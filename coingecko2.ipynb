# %% [markdown]
# coingecko https://www.coingecko.com/en/api/documentation

# %%
import pandas as pd
import requests
import csv

# %%
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=100&page=1&sparkline=false"
params = {'vs_currency': 'usd',
      'limit': 100}

response = requests.get(url, params=params)
response.json()
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 52051,
#   'market_cap': 976662986912,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1090453815793,
#   'total_volume': 35794929744,
#   'high_24h': 52034,
#   'low_24h': 51134,
#   'price_change_24h': 488.13,
#   'price_change_percentage_24h': 0.94667,
#   'market_cap_change_24h': 8694960131,
#   'market_cap_change_percentage_24h': 0.89827,
#   'circulating_supply': 18808612.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 64805,
#   'ath_change_percentage': -19.87255,
#   'ath_date': '2021-04-14T11:54:46.763Z',
#   'atl': 67.81,
#   'atl_change_percentage': 76477.40445,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:48.743Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 3952.97,
#   'market_cap': 463422200776,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 19953006798,
#   'high_24h': 3963.79,
#   'low_24h': 3875.9,
#   'price_change_24h': 4.81,
#   'price_change_percentage_24h': 0.12189,
#   'market_cap_change_24h': 375456821,
#   'market_cap_change_percentage_24h': 0.08108,
#   'circulating_supply': 117417360.8115,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4356.99,
#   'ath_change_percentage': -9.38458,
#   'ath_date': '2021-05-12T14:41:48.623Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 911747.15746,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 100.6207037597372,
#    'currency': 'btc',
#    'percentage': 10062.070375973719},
#   'last_updated': '2021-09-06T21:46:12.253Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 2.85,
#   'market_cap': 91154580998,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 127920731315,
#   'total_volume': 3539010553,
#   'high_24h': 2.93,
#   'low_24h': 2.82,
#   'price_change_24h': -0.083531747325,
#   'price_change_percentage_24h': -2.85024,
#   'market_cap_change_24h': -2769125857.992325,
#   'market_cap_change_percentage_24h': -2.94827,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -7.91173,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 14665.07704,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:07.072Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 498.18,
#   'market_cap': 76865779896,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 84824256663,
#   'total_volume': 1983107604,
#   'high_24h': 507.34,
#   'low_24h': 491.86,
#   'price_change_24h': -4.675806524001,
#   'price_change_percentage_24h': -0.92985,
#   'market_cap_change_24h': -667296882.4420013,
#   'market_cap_change_percentage_24h': -0.86066,
#   'circulating_supply': 154533651.9,
#   'total_supply': 170533651.9,
#   'max_supply': 170533651.9,
#   'ath': 686.31,
#   'ath_change_percentage': -27.5244,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1249105.33595,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:50.490Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 67939225660,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 76255752134,
#   'high_24h': 1.0,
#   'low_24h': 0.997274,
#   'price_change_24h': 0.00110398,
#   'price_change_percentage_24h': 0.11047,
#   'market_cap_change_24h': 677063134,
#   'market_cap_change_percentage_24h': 1.0066,
#   'circulating_supply': 67907378786.7102,
#   'total_supply': 67907378786.7102,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.38421,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.748,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:05:54.860Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 1.39,
#   'market_cap': 64716662930,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 139049014805,
#   'total_volume': 6815899285,
#   'high_24h': 1.4,
#   'low_24h': 1.29,
#   'price_change_24h': 0.097025,
#   'price_change_percentage_24h': 7.48714,
#   'market_cap_change_24h': 4360481396,
#   'market_cap_change_percentage_24h': 7.22458,
#   'circulating_supply': 46542338341.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -59.08458,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 51664.07935,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:01.596Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/coinmarketcap-solana-200.png?1616489452',
#   'current_price': 164.27,
#   'market_cap': 47482175847,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 79620414758,
#   'total_volume': 5169846557,
#   'high_24h': 164.32,
#   'low_24h': 139.14,
#   'price_change_24h': 23.99,
#   'price_change_percentage_24h': 17.09789,
#   'market_cap_change_24h': 6583165478,
#   'market_cap_change_percentage_24h': 16.09615,
#   'circulating_supply': 291398188.095557,
#   'total_supply': 488630611.0,
#   'max_supply': 488630611.0,
#   'ath': 163.0,
#   'ath_change_percentage': -0.01085,
#   'ath_date': '2021-09-06T21:04:49.294Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 32444.3101,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:08.940Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.308198,
#   'market_cap': 40330294486,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': None,
#   'total_volume': 2256496538,
#   'high_24h': 0.317522,
#   'low_24h': 0.303884,
#   'price_change_24h': -0.002517887398,
#   'price_change_percentage_24h': -0.81035,
#   'market_cap_change_24h': -319923143.06290436,
#   'market_cap_change_percentage_24h': -0.78701,
#   'circulating_supply': 131169791748.707,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -57.97218,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 353700.96297,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:38.417Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776',
#   'current_price': 34.43,
#   'market_cap': 35323303776,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': None,
#   'total_volume': 1649636806,
#   'high_24h': 34.9,
#   'low_24h': 33.33,
#   'price_change_24h': 0.02735889,
#   'price_change_percentage_24h': 0.07953,
#   'market_cap_change_24h': 26797251,
#   'market_cap_change_percentage_24h': 0.07592,
#   'circulating_supply': 1027240514.00922,
#   'total_supply': 1108189646.81232,
#   'max_supply': None,
#   'ath': 49.35,
#   'ath_change_percentage': -30.30278,
#   'ath_date': '2021-05-15T03:59:58.961Z',
#   'atl': 2.7,
#   'atl_change_percentage': 1175.08559,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:09.357Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 27857438533,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': None,
#   'total_volume': 1954778621,
#   'high_24h': 1.0,
#   'low_24h': 0.996132,
#   'price_change_24h': 0.00158543,
#   'price_change_percentage_24h': 0.15853,
#   'market_cap_change_24h': 62827389,
#   'market_cap_change_percentage_24h': 0.22604,
#   'circulating_supply': 27823772037.8592,
#   'total_supply': 27821880750.8992,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.62396,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 12.26241,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:08.069Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 35.66,
#   'market_cap': 16066075423,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 35662008237,
#   'total_volume': 2464849786,
#   'high_24h': 36.06,
#   'low_24h': 32.67,
#   'price_change_24h': 2.62,
#   'price_change_percentage_24h': 7.93591,
#   'market_cap_change_24h': 1212553780,
#   'market_cap_change_percentage_24h': 8.16341,
#   'circulating_supply': 450509553.9174637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -32.32552,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 23966.25819,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:10.755Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 29.59,
#   'market_cap': 15360908327,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 29548312051,
#   'total_volume': 674234980,
#   'high_24h': 30.21,
#   'low_24h': 28.77,
#   'price_change_24h': 0.309753,
#   'price_change_percentage_24h': 1.05806,
#   'market_cap_change_24h': 136859087,
#   'market_cap_change_percentage_24h': 0.89897,
#   'circulating_supply': 519857388.1320768,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -34.21096,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 2768.56864,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:48.575Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 794.45,
#   'market_cap': 14938402761,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 16652014030,
#   'total_volume': 5884731260,
#   'high_24h': 797.98,
#   'low_24h': 741.62,
#   'price_change_24h': 51.27,
#   'price_change_percentage_24h': 6.89914,
#   'market_cap_change_24h': 961753024,
#   'market_cap_change_percentage_24h': 6.88114,
#   'circulating_supply': 18838949.8967887,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -79.05465,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 930.68196,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:53.612Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 223.01,
#   'market_cap': 14873978878,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': None,
#   'total_volume': 3793610870,
#   'high_24h': 230.97,
#   'low_24h': 219.68,
#   'price_change_24h': -3.109881281525,
#   'price_change_percentage_24h': -1.37533,
#   'market_cap_change_24h': -176008039.40234184,
#   'market_cap_change_percentage_24h': -1.16949,
#   'circulating_supply': 66752614.5153875,
#   'total_supply': 84000000.0,
#   'max_supply': None,
#   'ath': 410.26,
#   'ath_change_percentage': -45.6879,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 19295.24057,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:00.837Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 32.42,
#   'market_cap': 12982926591,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 909542123,
#   'high_24h': 35.15,
#   'low_24h': 31.38,
#   'price_change_24h': -2.588709758269,
#   'price_change_percentage_24h': -7.39541,
#   'market_cap_change_24h': -966419618.8927498,
#   'market_cap_change_percentage_24h': -6.92806,
#   'circulating_supply': 400493292.02888,
#   'total_supply': 994421190.941183,
#   'max_supply': None,
#   'ath': 36.61,
#   'ath_change_percentage': -11.42049,
#   'ath_date': '2021-08-29T08:14:44.747Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 26525.55402,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:47.342Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 1.0,
#   'market_cap': 12555385630,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': None,
#   'total_volume': 6787270284,
#   'high_24h': 1.0,
#   'low_24h': 0.995727,
#   'price_change_24h': 0.00245415,
#   'price_change_percentage_24h': 0.24574,
#   'market_cap_change_24h': 44454916,
#   'market_cap_change_percentage_24h': 0.35533,
#   'circulating_supply': 12553977646.51,
#   'total_supply': 12553977646.51,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.34612,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 10.99016,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:27.934Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 79.97,
#   'market_cap': 12552408064,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 37480961613,
#   'total_volume': 1173957686,
#   'high_24h': 86.47,
#   'low_24h': 77.87,
#   'price_change_24h': 0.433704,
#   'price_change_percentage_24h': 0.54532,
#   'market_cap_change_24h': 95246573,
#   'market_cap_change_percentage_24h': 0.76459,
#   'circulating_supply': 157140097.36,
#   'total_supply': 469213710.0,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -88.59897,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 27.44,
#   'atl_change_percentage': 191.14912,
#   'atl_date': '2021-07-20T10:14:50.919Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:08.155Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 108.22,
#   'market_cap': 11057934897,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 213040935821,
#   'total_volume': 2957079439,
#   'high_24h': 117.87,
#   'low_24h': 106.11,
#   'price_change_24h': -9.651047342496,
#   'price_change_percentage_24h': -8.18806,
#   'market_cap_change_24h': -1005339210.0320759,
#   'market_cap_change_percentage_24h': -8.33388,
#   'circulating_supply': 102365769.0,
#   'total_supply': 1972167446.0,
#   'max_supply': 1972167446.0,
#   'ath': 236.84,
#   'ath_change_percentage': -54.42919,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 438.04693,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:59.422Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 1.65,
#   'market_cap': 10959697266,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 16483092871,
#   'total_volume': 1573876476,
#   'high_24h': 1.71,
#   'low_24h': 1.6,
#   'price_change_24h': -0.035900028814,
#   'price_change_percentage_24h': -2.12945,
#   'market_cap_change_24h': -167856988.63572884,
#   'market_cap_change_percentage_24h': -1.50848,
#   'circulating_supply': 6649053883.1,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.62,
#   'ath_change_percentage': -37.07782,
#   'ath_date': '2021-05-18T19:38:18.813Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 52347.67068,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 626.3708748308019,
#    'currency': 'usd',
#    'percentage': 62637.08748308019},
#   'last_updated': '2021-09-06T21:45:56.143Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 52069,
#   'market_cap': 10561023348,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 10561023348,
#   'total_volume': 288501697,
#   'high_24h': 52025,
#   'low_24h': 51159,
#   'price_change_24h': 572.73,
#   'price_change_percentage_24h': 1.11218,
#   'market_cap_change_24h': 294856513,
#   'market_cap_change_percentage_24h': 2.87212,
#   'circulating_supply': 203121.30943419,
#   'total_supply': 203121.30943419,
#   'max_supply': 203121.30943419,
#   'ath': 64565,
#   'ath_change_percentage': -19.4711,
#   'ath_date': '2021-04-14T12:00:05.340Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1556.28561,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:43.287Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 46.82,
#   'market_cap': 10279978263,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 33631415840,
#   'total_volume': 1120973383,
#   'high_24h': 50.94,
#   'low_24h': 45.95,
#   'price_change_24h': -2.047737094577,
#   'price_change_percentage_24h': -4.19054,
#   'market_cap_change_24h': -445171342.6966076,
#   'market_cap_change_percentage_24h': -4.15072,
#   'circulating_supply': 220079475.228676,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 59.4,
#   'ath_change_percentage': -21.26213,
#   'ath_date': '2021-02-10T22:23:34.616Z',
#   'atl': 2.8,
#   'atl_change_percentage': 1569.83034,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:23.397Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.150715,
#   'market_cap': 10038232368,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': None,
#   'total_volume': 754456392,
#   'high_24h': 0.155858,
#   'low_24h': 0.149209,
#   'price_change_24h': -0.001481600161,
#   'price_change_percentage_24h': -0.97348,
#   'market_cap_change_24h': -110112711.83511925,
#   'market_cap_change_percentage_24h': -1.08503,
#   'circulating_supply': 66760741299.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -46.48894,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 7743.02813,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 12.344785108791932,
#    'currency': 'eth',
#    'percentage': 1234.4785108791932},
#   'last_updated': '2021-09-06T21:45:54.611Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.423946,
#   'market_cap': 10023282236,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 21182719779,
#   'total_volume': 1627349100,
#   'high_24h': 0.428308,
#   'low_24h': 0.390024,
#   'price_change_24h': 0.03139047,
#   'price_change_percentage_24h': 7.99644,
#   'market_cap_change_24h': 722201101,
#   'market_cap_change_percentage_24h': 7.7647,
#   'circulating_supply': 23659954306.4565,
#   'total_supply': 50001802828.4414,
#   'max_supply': 50001802828.4414,
#   'ath': 0.875563,
#   'ath_change_percentage': -51.61523,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 88876.75011,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:48.394Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 74.07,
#   'market_cap': 9592888963,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': None,
#   'total_volume': 7755323078,
#   'high_24h': 76.52,
#   'low_24h': 71.77,
#   'price_change_24h': 1.65,
#   'price_change_percentage_24h': 2.27611,
#   'market_cap_change_24h': 209500109,
#   'market_cap_change_percentage_24h': 2.23267,
#   'circulating_supply': 129693726.639632,
#   'total_supply': 210700000.0,
#   'max_supply': None,
#   'ath': 167.09,
#   'ath_change_percentage': -55.73178,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 11926.20212,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 163.60817155943545,
#    'currency': 'usd',
#    'percentage': 16360.817155943545},
#   'last_updated': '2021-09-06T21:45:57.591Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 9.31,
#   'market_cap': 9308712856,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': None,
#   'total_volume': 998946427,
#   'high_24h': 9.41,
#   'low_24h': 7.91,
#   'price_change_24h': 1.34,
#   'price_change_percentage_24h': 16.85765,
#   'market_cap_change_24h': 1354473489,
#   'market_cap_change_percentage_24h': 17.02832,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -40.78055,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 22942.52101,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 61.07198608055946,
#    'currency': 'usd',
#    'percentage': 6107.198608055946},
#   'last_updated': '2021-09-06T21:45:59.040Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 74.3,
#   'market_cap': 7849209160,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 24951924650,
#   'total_volume': 1803284664,
#   'high_24h': 77.04,
#   'low_24h': 62.43,
#   'price_change_24h': 10.2,
#   'price_change_percentage_24h': 15.92191,
#   'market_cap_change_24h': 1053172219,
#   'market_cap_change_percentage_24h': 15.49686,
#   'circulating_supply': 105957291.21874323,
#   'total_supply': 336828627.285971,
#   'max_supply': 336828627.285971,
#   'ath': 77.04,
#   'ath_change_percentage': -3.80781,
#   'ath_date': '2021-09-06T14:14:49.165Z',
#   'atl': 1.15,
#   'atl_change_percentage': 6345.37939,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:48.902Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 79.2,
#   'market_cap': 7436162135,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': None,
#   'total_volume': 20797896,
#   'high_24h': 79.56,
#   'low_24h': 77.82,
#   'price_change_24h': 0.098685,
#   'price_change_percentage_24h': 0.12476,
#   'market_cap_change_24h': 27947662,
#   'market_cap_change_percentage_24h': 0.37725,
#   'circulating_supply': 93939211.0863374,
#   'total_supply': 93939211.0863374,
#   'max_supply': None,
#   'ath': 87.15,
#   'ath_change_percentage': -9.16459,
#   'ath_date': '2021-05-12T14:49:23.076Z',
#   'atl': 1.89,
#   'atl_change_percentage': 4096.56451,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:24.599Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.103786,
#   'market_cap': 7424656064,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 1398446916,
#   'high_24h': 0.107184,
#   'low_24h': 0.102337,
#   'price_change_24h': -0.000500493603,
#   'price_change_percentage_24h': -0.47992,
#   'market_cap_change_24h': -34352514.86218643,
#   'market_cap_change_percentage_24h': -0.46055,
#   'circulating_supply': 71660220128.0,
#   'total_supply': 100850743812.0,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -55.27779,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 5642.21477,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 53.624278547686735,
#    'currency': 'usd',
#    'percentage': 5362.427854768674},
#   'last_updated': '2021-09-06T21:45:59.699Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 25.51,
#   'market_cap': 7111146601,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 709846384,
#   'high_24h': 26.9,
#   'low_24h': 24.78,
#   'price_change_24h': 0.067013,
#   'price_change_percentage_24h': 0.26336,
#   'market_cap_change_24h': 38315690,
#   'market_cap_change_percentage_24h': 0.54173,
#   'circulating_supply': 278741933.433749,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 31.7,
#   'ath_change_percentage': -19.52622,
#   'ath_date': '2021-05-07T16:18:33.469Z',
#   'atl': 1.16,
#   'atl_change_percentage': 2099.17701,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 254.1285413629946,
#    'currency': 'usd',
#    'percentage': 25412.85413629946},
#   'last_updated': '2021-09-06T21:46:03.201Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 23.28,
#   'market_cap': 6231095028,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': None,
#   'total_volume': 350527232,
#   'high_24h': 23.87,
#   'low_24h': 22.77,
#   'price_change_24h': 0.236459,
#   'price_change_percentage_24h': 1.02595,
#   'market_cap_change_24h': 68244433,
#   'market_cap_change_percentage_24h': 1.10735,
#   'circulating_supply': 267436117.72,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -47.05325,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 3912.9274,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:10.421Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/dai-multi-collateral-mcd.png?1574218774',
#   'current_price': 1.0,
#   'market_cap': 6182088644,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 6182088644,
#   'total_volume': 421948081,
#   'high_24h': 1.0,
#   'low_24h': 0.997199,
#   'price_change_24h': -0.003588456359,
#   'price_change_percentage_24h': -0.35755,
#   'market_cap_change_24h': 17653001,
#   'market_cap_change_percentage_24h': 0.28637,
#   'circulating_supply': 6181931826.52944,
#   'total_supply': 6181931826.52944,
#   'max_supply': 6181931826.52944,
#   'ath': 1.22,
#   'ath_change_percentage': -17.95878,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.71498,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:05:28.974Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 6.19,
#   'market_cap': 5977679550,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': None,
#   'total_volume': 2820041826,
#   'high_24h': 6.37,
#   'low_24h': 6.01,
#   'price_change_24h': -0.042154409999,
#   'price_change_percentage_24h': -0.6764,
#   'market_cap_change_24h': -38348279.23418522,
#   'market_cap_change_percentage_24h': -0.63744,
#   'circulating_supply': 966290625.2354,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -72.76152,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 1131.33105,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': 5.252570145264185,
#    'currency': 'usd',
#    'percentage': 525.2570145264185},
#   'last_updated': '2021-09-06T21:45:33.346Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 316.78,
#   'market_cap': 5690157627,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': None,
#   'total_volume': 302437034,
#   'high_24h': 320.65,
#   'low_24h': 305.24,
#   'price_change_24h': 2.15,
#   'price_change_percentage_24h': 0.68355,
#   'market_cap_change_24h': 39121139,
#   'market_cap_change_percentage_24h': 0.69228,
#   'circulating_supply': 17987923.6204643,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -41.6514,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 146279.9847,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:59.043Z'},
#  {'id': 'bitcoin-cash-abc-2',
#   'symbol': 'bcha',
#   'name': 'Bitcoin Cash ABC',
#   'image': 'https://assets.coingecko.com/coins/images/13120/large/Logo_final-21.png?1624892810',
#   'current_price': 295.03,
#   'market_cap': 5546373575,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': None,
#   'total_volume': 731858771,
#   'high_24h': 328.45,
#   'low_24h': 288.64,
#   'price_change_24h': -15.976144512727,
#   'price_change_percentage_24h': -5.13685,
#   'market_cap_change_24h': -315368915.5532589,
#   'market_cap_change_percentage_24h': -5.38012,
#   'circulating_supply': 18794058.3967894,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 378.12,
#   'ath_change_percentage': -21.95081,
#   'ath_date': '2021-09-04T17:15:31.514Z',
#   'atl': 9.21,
#   'atl_change_percentage': 3104.38888,
#   'atl_date': '2020-11-15T18:28:32.658Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:49.588Z'},
#  {'id': 'ecash',
#   'symbol': 'xec',
#   'name': 'eCash',
#   'image': 'https://assets.coingecko.com/coins/images/16646/large/Logo_final-22.png?1628239446',
#   'current_price': 0.00028977,
#   'market_cap': 5453534836,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 433823556,
#   'high_24h': 0.00031737,
#   'low_24h': 0.00028087,
#   'price_change_24h': -1.7764715e-05,
#   'price_change_percentage_24h': -5.77642,
#   'market_cap_change_24h': 5453534836,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 18836114646789.4,
#   'total_supply': 21000000000000.0,
#   'max_supply': None,
#   'ath': 0.00038001,
#   'ath_change_percentage': -23.81175,
#   'ath_date': '2021-09-04T17:09:31.137Z',
#   'atl': 1.847e-05,
#   'atl_change_percentage': 1467.55204,
#   'atl_date': '2021-07-20T20:49:46.212Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:05.064Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 412.06,
#   'market_cap': 5417403129,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 6589387235,
#   'total_volume': 396954896,
#   'high_24h': 423.81,
#   'low_24h': 404.91,
#   'price_change_24h': -8.431153572483,
#   'price_change_percentage_24h': -2.00507,
#   'market_cap_change_24h': -103775860.22286606,
#   'market_cap_change_percentage_24h': -1.8796,
#   'circulating_supply': 13154250.461165803,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -37.75319,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 1482.74837,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:04.243Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://assets.coingecko.com/coins/images/12632/large/pancakeswap-cake-logo_%281%29.png?1629359065',
#   'current_price': 24.65,
#   'market_cap': 5374495526,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': None,
#   'total_volume': 292305577,
#   'high_24h': 25.22,
#   'low_24h': 24.18,
#   'price_change_24h': 0.330973,
#   'price_change_percentage_24h': 1.36096,
#   'market_cap_change_24h': 72737963,
#   'market_cap_change_percentage_24h': 1.37196,
#   'circulating_supply': 218284410.742696,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 43.96,
#   'ath_change_percentage': -43.9927,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 12563.71236,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:07.276Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 1.05,
#   'market_cap': 5200823776,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 10492205291,
#   'total_volume': 412286533,
#   'high_24h': 1.06,
#   'low_24h': 0.976856,
#   'price_change_24h': 0.051844,
#   'price_change_percentage_24h': 5.19163,
#   'market_cap_change_24h': 253357017,
#   'market_cap_change_percentage_24h': 5.12094,
#   'circulating_supply': 4956845231.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -63.07315,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 916.20753,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:58.497Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02221203,
#   'market_cap': 5176814906,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': None,
#   'total_volume': 48801423,
#   'high_24h': 0.02221247,
#   'low_24h': 0.02206443,
#   'price_change_24h': 6.729e-05,
#   'price_change_percentage_24h': 0.30386,
#   'market_cap_change_24h': 45787537,
#   'market_cap_change_percentage_24h': 0.89237,
#   'circulating_supply': 233487969512.303,
#   'total_supply': 233487969512.303,
#   'max_supply': None,
#   'ath': 0.058843,
#   'ath_change_percentage': -62.32092,
#   'ath_date': '2020-10-21T11:24:27.820Z',
#   'atl': 0.00620705,
#   'atl_change_percentage': 257.20093,
#   'atl_date': '2021-03-04T08:11:37.438Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:23.420Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 1.84,
#   'market_cap': 5125407858,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': None,
#   'total_volume': 342018492,
#   'high_24h': 1.95,
#   'low_24h': 1.77,
#   'price_change_24h': 0.058509,
#   'price_change_percentage_24h': 3.27691,
#   'market_cap_change_24h': 167465062,
#   'market_cap_change_percentage_24h': 3.37771,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -64.86833,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 2158.74913,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 25.45559491300098,
#    'currency': 'btc',
#    'percentage': 2545.5594913000978},
#   'last_updated': '2021-09-06T21:45:57.152Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.200808,
#   'market_cap': 5068215767,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': None,
#   'total_volume': 91565654,
#   'high_24h': 0.200887,
#   'low_24h': 0.183343,
#   'price_change_24h': 0.01512742,
#   'price_change_percentage_24h': 8.14699,
#   'market_cap_change_24h': 384993715,
#   'market_cap_change_percentage_24h': 8.2207,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.27702,
#   'ath_change_percentage': -27.49747,
#   'ath_date': '2021-02-22T11:33:57.751Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1557.20457,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:12.890Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 1.42,
#   'market_cap': 4993700987,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 14171853071,
#   'total_volume': 462304564,
#   'high_24h': 1.44,
#   'low_24h': 1.3,
#   'price_change_24h': 0.101315,
#   'price_change_percentage_24h': 7.68358,
#   'market_cap_change_24h': 347488946,
#   'market_cap_change_percentage_24h': 7.47897,
#   'circulating_supply': 3523675387.98048,
#   'total_supply': 5763239775.93481,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -60.19143,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 1245.83718,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.40837480771641377,
#    'currency': 'usd',
#    'percentage': -40.837480771641374},
#   'last_updated': '2021-09-06T21:46:08.162Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 5.69,
#   'market_cap': 4787873509,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': None,
#   'total_volume': 385575806,
#   'high_24h': 5.73,
#   'low_24h': 5.4,
#   'price_change_24h': 0.179569,
#   'price_change_percentage_24h': 3.26023,
#   'market_cap_change_24h': 147651803,
#   'market_cap_change_percentage_24h': 3.182,
#   'circulating_supply': 843704693.712206,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 8.27,
#   'ath_change_percentage': -31.34954,
#   'ath_date': '2021-05-07T02:09:26.683Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 1519.17551,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 11.100951941073943,
#    'currency': 'usd',
#    'percentage': 1110.0951941073943},
#   'last_updated': '2021-09-06T21:46:06.011Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02165253,
#   'market_cap': 4712013756,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 111752412,
#   'high_24h': 0.02164635,
#   'low_24h': 0.0215142,
#   'price_change_24h': 6.123e-05,
#   'price_change_percentage_24h': 0.28356,
#   'market_cap_change_24h': 113573396,
#   'market_cap_change_percentage_24h': 2.46982,
#   'circulating_supply': 218010314664.599,
#   'total_supply': 218010314664.599,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -31.58238,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 196.54373,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:24.188Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 80.75,
#   'market_cap': 4668559011,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 21798839965,
#   'total_volume': 986058990,
#   'high_24h': 84.56,
#   'low_24h': 76.43,
#   'price_change_24h': -1.895467048326,
#   'price_change_percentage_24h': -2.29339,
#   'market_cap_change_24h': -99458777.5863514,
#   'market_cap_change_percentage_24h': -2.08596,
#   'circulating_supply': 57824679.437666714,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 93.68,
#   'ath_change_percentage': -13.82929,
#   'ath_date': '2021-09-04T14:30:06.167Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 65150.72694,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:13.797Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 3924.69,
#   'market_cap': 4657227486,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 4657227486,
#   'total_volume': 16749939,
#   'high_24h': 3943.29,
#   'low_24h': 3864.15,
#   'price_change_24h': -2.650915520602,
#   'price_change_percentage_24h': -0.0675,
#   'market_cap_change_24h': 21802669,
#   'market_cap_change_percentage_24h': 0.47035,
#   'circulating_supply': 1187456.85450562,
#   'total_supply': 1187456.85450562,
#   'max_supply': 1187456.85450562,
#   'ath': 4309.29,
#   'ath_change_percentage': -8.94949,
#   'ath_date': '2021-05-12T09:57:17.253Z',
#   'atl': 482.9,
#   'atl_change_percentage': 712.52075,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:43:14.574Z'},
#  {'id': 'neo',
#   'symbol': 'neo',
#   'name': 'NEO',
#   'image': 'https://assets.coingecko.com/coins/images/480/large/NEO_512_512.png?1594357361',
#   'current_price': 63.99,
#   'market_cap': 4501904109,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': None,
#   'total_volume': 1111689425,
#   'high_24h': 66.31,
#   'low_24h': 62.26,
#   'price_change_24h': 1.24,
#   'price_change_percentage_24h': 1.97711,
#   'market_cap_change_24h': 87368420,
#   'market_cap_change_percentage_24h': 1.97911,
#   'circulating_supply': 70530000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 198.38,
#   'ath_change_percentage': -67.82478,
#   'ath_date': '2018-01-15T00:00:00.000Z',
#   'atl': 0.078349,
#   'atl_change_percentage': 81367.92997,
#   'atl_date': '2016-10-21T00:00:00.000Z',
#   'roi': {'times': 1776.5459053258653,
#    'currency': 'usd',
#    'percentage': 177654.59053258653},
#   'last_updated': '2021-09-06T21:45:38.156Z'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'image': 'https://assets.coingecko.com/coins/images/3370/large/5ZOu7brX_400x400.jpg?1612437252',
#   'current_price': 340.27,
#   'market_cap': 4470271596,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 4938943518,
#   'total_volume': 713129413,
#   'high_24h': 379.03,
#   'low_24h': 290.01,
#   'price_change_24h': 50.26,
#   'price_change_percentage_24h': 17.33149,
#   'market_cap_change_24h': 672413710,
#   'market_cap_change_percentage_24h': 17.70508,
#   'circulating_supply': 13225867.469289193,
#   'total_supply': 14612493.0,
#   'max_supply': 14612493.0,
#   'ath': 379.03,
#   'ath_change_percentage': -10.82534,
#   'ath_date': '2021-09-06T04:44:25.671Z',
#   'atl': 0.215773,
#   'atl_change_percentage': 156543.35187,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'roi': {'times': 36.01498873749227,
#    'currency': 'eth',
#    'percentage': 3601.498873749227},
#   'last_updated': '2021-09-06T21:45:51.977Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 1.63,
#   'market_cap': 4070835041,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': None,
#   'total_volume': 61920719,
#   'high_24h': 1.66,
#   'low_24h': 1.6,
#   'price_change_24h': 0.02171767,
#   'price_change_percentage_24h': 1.35266,
#   'market_cap_change_24h': 58937818,
#   'market_cap_change_percentage_24h': 1.46908,
#   'circulating_supply': 2502010658.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -62.50367,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 2591.83393,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:43.028Z'},
#  {'id': 'fantom',
#   'symbol': 'ftm',
#   'name': 'Fantom',
#   'image': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#   'current_price': 1.43,
#   'market_cap': 3655958329,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 4567874867,
#   'total_volume': 997789803,
#   'high_24h': 1.46,
#   'low_24h': 1.2,
#   'price_change_24h': 0.209978,
#   'price_change_percentage_24h': 17.15738,
#   'market_cap_change_24h': 530375861,
#   'market_cap_change_percentage_24h': 16.96886,
#   'circulating_supply': 2541152731.01,
#   'total_supply': 3175000000.0,
#   'max_supply': 3175000000.0,
#   'ath': 1.46,
#   'ath_change_percentage': -1.63829,
#   'ath_date': '2021-09-06T20:30:28.945Z',
#   'atl': 0.00190227,
#   'atl_change_percentage': 75530.74316,
#   'atl_date': '2020-03-13T02:25:38.280Z',
#   'roi': {'times': 46.79379926943496,
#    'currency': 'usd',
#    'percentage': 4679.379926943497},
#   'last_updated': '2021-09-06T21:45:42.785Z'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'image': 'https://assets.coingecko.com/coins/images/6799/large/BSV.png?1558947902',
#   'current_price': 193.25,
#   'market_cap': 3632386908,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': None,
#   'total_volume': 436600530,
#   'high_24h': 198.91,
#   'low_24h': 188.25,
#   'price_change_24h': 3.04,
#   'price_change_percentage_24h': 1.60019,
#   'market_cap_change_24h': 56223145,
#   'market_cap_change_percentage_24h': 1.57216,
#   'circulating_supply': 18835395.394239,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 489.75,
#   'ath_change_percentage': -60.61101,
#   'ath_date': '2021-04-16T17:09:04.630Z',
#   'atl': 42.02,
#   'atl_change_percentage': 359.1154,
#   'atl_date': '2018-11-23T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:34.183Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 7.21e-06,
#   'market_cap': 3583291618,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': None,
#   'total_volume': 315011920,
#   'high_24h': 7.59e-06,
#   'low_24h': 7.11e-06,
#   'price_change_24h': -2.34218e-07,
#   'price_change_percentage_24h': -3.14647,
#   'market_cap_change_24h': -116544307.05699205,
#   'market_cap_change_percentage_24h': -3.14999,
#   'circulating_supply': 497730966630395.75,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 3.791e-05,
#   'ath_change_percentage': -81.00857,
#   'ath_date': '2021-05-10T22:53:42.945Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 12773545.0073,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:36.864Z'},
#  {'id': 'kusama',
#   'symbol': 'ksm',
#   'name': 'Kusama',
#   'image': 'https://assets.coingecko.com/coins/images/9568/large/m4zRhP5e_400x400.jpg?1576190080',
#   'current_price': 394.57,
#   'market_cap': 3542601714,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 3944947689,
#   'total_volume': 245702606,
#   'high_24h': 405.41,
#   'low_24h': 382.43,
#   'price_change_24h': -7.667274048936,
#   'price_change_percentage_24h': -1.90616,
#   'market_cap_change_24h': -68360910.10213423,
#   'market_cap_change_percentage_24h': -1.89315,
#   'circulating_supply': 8980098.074112339,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 621.71,
#   'ath_change_percentage': -36.53955,
#   'ath_date': '2021-05-18T05:04:41.858Z',
#   'atl': 0.876572,
#   'atl_change_percentage': 44909.04974,
#   'atl_date': '2020-01-14T19:20:20.768Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:32.073Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 178.21,
#   'market_cap': 3511988299,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 122304306,
#   'high_24h': 185.85,
#   'low_24h': 174.96,
#   'price_change_24h': 1.71,
#   'price_change_percentage_24h': 0.96965,
#   'market_cap_change_24h': 38865335,
#   'market_cap_change_percentage_24h': 1.11903,
#   'circulating_supply': 19701871.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 243.92,
#   'ath_change_percentage': -26.87786,
#   'ath_date': '2021-04-12T02:24:35.343Z',
#   'atl': 6.51,
#   'atl_change_percentage': 2641.20486,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
# ...
#   'total_volume': 901274423,
#   'high_24h': 16.79,
#   'low_24h': 15.47,
#   'price_change_24h': 0.117979,
#   'price_change_percentage_24h': 0.75323,
#   'market_cap_change_24h': 8470733,
#   'market_cap_change_percentage_24h': 0.52158,
#   'circulating_supply': 103709998.0,
#   'total_supply': 107822406.0,
#   'max_supply': None,
#   'ath': 100.22,
#   'ath_change_percentage': -84.29409,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 0.783142,
#   'atl_change_percentage': 1909.99168,
#   'atl_date': '2020-03-13T02:22:57.149Z',
#   'roi': {'times': 51.6036841570093,
#    'currency': 'usd',
#    'percentage': 5160.36841570093},
#   'last_updated': '2021-09-06T21:46:08.521Z'},
#  {'id': 'flow',
#   'symbol': 'flow',
#   'name': 'Flow',
#   'image': 'https://assets.coingecko.com/coins/images/13446/large/flow_logo.jpg?1608631239',
#   'current_price': 25.87,
#   'market_cap': 1571532692,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': None,
#   'total_volume': 142886593,
#   'high_24h': 26.5,
#   'low_24h': 25.39,
#   'price_change_24h': 0.092754,
#   'price_change_percentage_24h': 0.35977,
#   'market_cap_change_24h': 12977298,
#   'market_cap_change_percentage_24h': 0.83265,
#   'circulating_supply': 60749508.1158945,
#   'total_supply': 1368390492.48566,
#   'max_supply': None,
#   'ath': 42.4,
#   'ath_change_percentage': -38.97773,
#   'ath_date': '2021-04-05T13:49:10.098Z',
#   'atl': 4.95,
#   'atl_change_percentage': 422.66069,
#   'atl_date': '2021-01-27T15:34:04.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:08.269Z'},
#  {'id': 'yearn-finance',
#   'symbol': 'yfi',
#   'name': 'yearn.finance',
#   'image': 'https://assets.coingecko.com/coins/images/11849/large/yfi-192x192.png?1598325330',
#   'current_price': 41959,
#   'market_cap': 1495422409,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 1536204134,
#   'total_volume': 317668992,
#   'high_24h': 43341,
#   'low_24h': 41727,
#   'price_change_24h': -1340.78335449809,
#   'price_change_percentage_24h': -3.09652,
#   'market_cap_change_24h': -51096625.61359048,
#   'market_cap_change_percentage_24h': -3.30398,
#   'circulating_supply': 35692.624968711796,
#   'total_supply': 36666.0,
#   'max_supply': 36666.0,
#   'ath': 90787,
#   'ath_change_percentage': -53.82644,
#   'ath_date': '2021-05-12T00:29:37.713Z',
#   'atl': 31.65,
#   'atl_change_percentage': 132367.53431,
#   'atl_date': '2020-07-18T12:26:27.150Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:12.562Z'},
#  {'id': 'bitcoin-gold',
#   'symbol': 'btg',
#   'name': 'Bitcoin Gold',
#   'image': 'https://assets.coingecko.com/coins/images/1043/large/bitcoin-gold-logo.png?1547034978',
#   'current_price': 82.63,
#   'market_cap': 1445361967,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': None,
#   'total_volume': 81190961,
#   'high_24h': 84.08,
#   'low_24h': 81.18,
#   'price_change_24h': -0.184844908695,
#   'price_change_percentage_24h': -0.22321,
#   'market_cap_change_24h': -4905892.465975761,
#   'market_cap_change_percentage_24h': -0.33827,
#   'circulating_supply': 17513924.0,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 456.25,
#   'ath_change_percentage': -81.91186,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 4.25,
#   'atl_change_percentage': 1839.76891,
#   'atl_date': '2020-03-13T02:22:52.902Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:47.697Z'},
#  {'id': 'basic-attention-token',
#   'symbol': 'bat',
#   'name': 'Basic Attention Token',
#   'image': 'https://assets.coingecko.com/coins/images/677/large/basic-attention-token.png?1547034427',
#   'current_price': 0.962311,
#   'market_cap': 1432400521,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1441676548,
#   'total_volume': 190403268,
#   'high_24h': 0.98739,
#   'low_24h': 0.936635,
#   'price_change_24h': -0.01076125754,
#   'price_change_percentage_24h': -1.10591,
#   'market_cap_change_24h': -21390489.477897406,
#   'market_cap_change_percentage_24h': -1.47136,
#   'circulating_supply': 1490348708.4473505,
#   'total_supply': 1500000000.0,
#   'max_supply': 1500000000.0,
#   'ath': 1.63,
#   'ath_change_percentage': -41.08507,
#   'ath_date': '2021-04-09T19:03:22.356Z',
#   'atl': 0.072394,
#   'atl_change_percentage': 1227.62422,
#   'atl_date': '2017-07-16T00:00:00.000Z',
#   'roi': {'times': 0.5580537552099079,
#    'currency': 'eth',
#    'percentage': 55.805375520990786},
#   'last_updated': '2021-09-06T21:45:52.677Z'},
#  {'id': 'iostoken',
#   'symbol': 'iost',
#   'name': 'IOST',
#   'image': 'https://assets.coingecko.com/coins/images/2523/large/IOST.png?1557555183',
#   'current_price': 0.062332,
#   'market_cap': 1419881477,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 5620612652,
#   'total_volume': 385331808,
#   'high_24h': 0.062946,
#   'low_24h': 0.058634,
#   'price_change_24h': 0.00147204,
#   'price_change_percentage_24h': 2.41872,
#   'market_cap_change_24h': 37278119,
#   'market_cap_change_percentage_24h': 2.69623,
#   'circulating_supply': 22735836966.197,
#   'total_supply': 22735836966.197,
#   'max_supply': 90000000000.0,
#   'ath': 0.129829,
#   'ath_change_percentage': -51.89717,
#   'ath_date': '2018-01-24T00:00:00.000Z',
#   'atl': 0.00160309,
#   'atl_change_percentage': 3795.68277,
#   'atl_date': '2020-03-13T02:25:35.257Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:55.919Z'},
#  {'id': 'mdex',
#   'symbol': 'mdx',
#   'name': 'Mdex',
#   'image': 'https://assets.coingecko.com/coins/images/13775/large/mdex.png?1611739676',
#   'current_price': 2.16,
#   'market_cap': 1402041669,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': None,
#   'total_volume': 112408015,
#   'high_24h': 2.21,
#   'low_24h': 1.78,
#   'price_change_24h': 0.361226,
#   'price_change_percentage_24h': 20.13204,
#   'market_cap_change_24h': 224977434,
#   'market_cap_change_percentage_24h': 19.11344,
#   'circulating_supply': 650681553.22546,
#   'total_supply': 452988758.45796,
#   'max_supply': None,
#   'ath': 10.11,
#   'ath_change_percentage': -78.68875,
#   'ath_date': '2021-02-22T07:08:38.957Z',
#   'atl': 1.05,
#   'atl_change_percentage': 104.69129,
#   'atl_date': '2021-07-30T09:34:16.681Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:44:38.506Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 1.0,
#   'market_cap': 1401945498,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': None,
#   'total_volume': 66342350,
#   'high_24h': 1.0,
#   'low_24h': 0.995181,
#   'price_change_24h': 0.00216608,
#   'price_change_percentage_24h': 0.21684,
#   'market_cap_change_24h': 12021042,
#   'market_cap_change_percentage_24h': 0.86487,
#   'circulating_supply': 1401641737.0833,
#   'total_supply': 1402016729.5833,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.19974,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.20754,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:54.093Z'},
#  {'id': 'ravencoin',
#   'symbol': 'rvn',
#   'name': 'Ravencoin',
#   'image': 'https://assets.coingecko.com/coins/images/3412/large/ravencoin.png?1548386057',
#   'current_price': 0.145285,
#   'market_cap': 1392684361,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': None,
#   'total_volume': 127267495,
#   'high_24h': 0.152441,
#   'low_24h': 0.142232,
#   'price_change_24h': -0.005303359784,
#   'price_change_percentage_24h': -3.52176,
#   'market_cap_change_24h': -47966531.9770987,
#   'market_cap_change_percentage_24h': -3.3295,
#   'circulating_supply': 9593530000.0,
#   'total_supply': 21000000000.0,
#   'max_supply': None,
#   'ath': 0.285218,
#   'ath_change_percentage': -49.1024,
#   'ath_date': '2021-02-20T11:19:07.791Z',
#   'atl': 0.00893232,
#   'atl_change_percentage': 1525.21134,
#   'atl_date': '2020-03-13T02:30:00.004Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:04.994Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 1.04,
#   'market_cap': 1376767384,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 2275737022,
#   'total_volume': 174152401,
#   'high_24h': 1.08,
#   'low_24h': 1.02,
#   'price_change_24h': -0.022294684786,
#   'price_change_percentage_24h': -2.1008,
#   'market_cap_change_24h': -27492982.41645074,
#   'market_cap_change_percentage_24h': -1.95783,
#   'circulating_supply': 1327372145.9864838,
#   'total_supply': 2194088827.32015,
#   'max_supply': 2194088827.32015,
#   'ath': 1.6,
#   'ath_change_percentage': -35.0377,
#   'ath_date': '2021-05-07T15:54:15.763Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 11129.126,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 50.9475856566832,
#    'currency': 'usd',
#    'percentage': 5094.75856566832},
#   'last_updated': '2021-09-06T21:45:56.725Z'},
#  {'id': 'harmony',
#   'symbol': 'one',
#   'name': 'Harmony',
#   'image': 'https://assets.coingecko.com/coins/images/4344/large/Y88JAze.png?1565065793',
#   'current_price': 0.130531,
#   'market_cap': 1375900151,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 1716635899,
#   'total_volume': 68747573,
#   'high_24h': 0.133389,
#   'low_24h': 0.126477,
#   'price_change_24h': -0.001452758749,
#   'price_change_percentage_24h': -1.10071,
#   'market_cap_change_24h': -12743264.716475964,
#   'market_cap_change_percentage_24h': -0.91768,
#   'circulating_supply': 10544696227.7931,
#   'total_supply': 13156044839.793139,
#   'max_supply': 13156044839.793139,
#   'ath': 0.222092,
#   'ath_change_percentage': -41.24842,
#   'ath_date': '2021-03-29T08:19:36.363Z',
#   'atl': 0.00127355,
#   'atl_change_percentage': 10145.5702,
#   'atl_date': '2020-03-13T02:24:14.005Z',
#   'roi': {'times': 40.11210033896428,
#    'currency': 'usd',
#    'percentage': 4011.2100338964283},
#   'last_updated': '2021-09-06T21:45:41.155Z'},
#  {'id': 'telcoin',
#   'symbol': 'tel',
#   'name': 'Telcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1899/large/tel.png?1547036203',
#   'current_price': 0.02377477,
#   'market_cap': 1347183933,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': None,
#   'total_volume': 17666610,
#   'high_24h': 0.02472607,
#   'low_24h': 0.02296479,
#   'price_change_24h': -0.000896592373,
#   'price_change_percentage_24h': -3.63414,
#   'market_cap_change_24h': -56343133.87691951,
#   'market_cap_change_percentage_24h': -4.0144,
#   'circulating_supply': 56989406904.06,
#   'total_supply': 100000000000.0,
#   'max_supply': None,
#   'ath': 0.064483,
#   'ath_change_percentage': -63.34027,
#   'ath_date': '2021-05-11T00:32:24.043Z',
#   'atl': 6.474e-05,
#   'atl_change_percentage': 36416.16057,
#   'atl_date': '2020-03-13T02:24:47.992Z',
#   'roi': {'times': 22.77476856898121,
#    'currency': 'usd',
#    'percentage': 2277.476856898121},
#   'last_updated': '2021-09-06T21:44:06.457Z'},
#  {'id': 'omisego',
#   'symbol': 'omg',
#   'name': 'OMG Network',
#   'image': 'https://assets.coingecko.com/coins/images/776/large/OMG_Network.jpg?1591167168',
#   'current_price': 9.26,
#   'market_cap': 1294423754,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 1294423754,
#   'total_volume': 2816397386,
#   'high_24h': 10.04,
#   'low_24h': 7.96,
#   'price_change_24h': 1.3,
#   'price_change_percentage_24h': 16.35274,
#   'market_cap_change_24h': 184444392,
#   'market_cap_change_percentage_24h': 16.61692,
#   'circulating_supply': 140245398.245133,
#   'total_supply': 140245398.245133,
#   'max_supply': 140245398.245133,
#   'ath': 25.62,
#   'ath_change_percentage': -63.97559,
#   'ath_date': '2018-01-13T00:00:00.000Z',
#   'atl': 0.350917,
#   'atl_change_percentage': 2530.16684,
#   'atl_date': '2020-03-13T02:30:10.072Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:58.306Z'},
#  {'id': 'safemoon',
#   'symbol': 'safemoon',
#   'name': 'SafeMoon',
#   'image': 'https://assets.coingecko.com/coins/images/14362/large/174x174-white.png?1617174846',
#   'current_price': 2.21e-06,
#   'market_cap': 1270541551,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': None,
#   'total_volume': 13071406,
#   'high_24h': 2.42e-06,
#   'low_24h': 2.16e-06,
#   'price_change_24h': -1.96464e-07,
#   'price_change_percentage_24h': -8.17847,
#   'market_cap_change_24h': -102998284.44188571,
#   'market_cap_change_percentage_24h': -7.49875,
#   'circulating_supply': 576736249684172.6,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 1.094e-05,
#   'ath_change_percentage': -79.86941,
#   'ath_date': '2021-05-11T20:32:53.513Z',
#   'atl': 4.436e-08,
#   'atl_change_percentage': 4866.20113,
#   'atl_date': '2021-03-14T19:51:56.741Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:10.556Z'},
#  {'id': 'zencash',
#   'symbol': 'zen',
#   'name': 'Horizen',
#   'image': 'https://assets.coingecko.com/coins/images/691/large/horizen.png?1555052241',
#   'current_price': 105.9,
#   'market_cap': 1216692912,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 57426235,
#   'high_24h': 110.31,
#   'low_24h': 104.81,
#   'price_change_24h': -3.499938755939,
#   'price_change_percentage_24h': -3.19925,
#   'market_cap_change_24h': -37568999.62813592,
#   'market_cap_change_percentage_24h': -2.99531,
#   'circulating_supply': 11491706.25,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 165.92,
#   'ath_change_percentage': -36.16909,
#   'ath_date': '2021-05-08T06:00:30.087Z',
#   'atl': 3.26,
#   'atl_change_percentage': 3144.1801,
#   'atl_date': '2019-10-17T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:10.871Z'},
#  {'id': 'xsushi',
#   'symbol': 'xsushi',
#   'name': 'xSUSHI',
#   'image': 'https://assets.coingecko.com/coins/images/13725/large/xsushi.png?1612538526',
#   'current_price': 16.19,
#   'market_cap': 1213102633,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': None,
#   'total_volume': 1567199,
#   'high_24h': 16.8,
#   'low_24h': 15.94,
#   'price_change_24h': -0.561941226756,
#   'price_change_percentage_24h': -3.35419,
#   'market_cap_change_24h': -40900178.214959145,
#   'market_cap_change_percentage_24h': -3.26157,
#   'circulating_supply': 74922326.6650337,
#   'total_supply': 74922326.6650337,
#   'max_supply': None,
#   'ath': 26.33,
#   'ath_change_percentage': -38.5057,
#   'ath_date': '2021-03-13T23:01:02.266Z',
#   'atl': 6.04,
#   'atl_change_percentage': 168.02181,
#   'atl_date': '2021-01-22T01:04:22.350Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:42:00.902Z'},
#  {'id': 'siacoin',
#   'symbol': 'sc',
#   'name': 'Siacoin',
#   'image': 'https://assets.coingecko.com/coins/images/289/large/siacoin.png?1548386465',
#   'current_price': 0.02461032,
#   'market_cap': 1200528322,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': None,
#   'total_volume': 183183241,
#   'high_24h': 0.02551302,
#   'low_24h': 0.02387008,
#   'price_change_24h': 0.00049918,
#   'price_change_percentage_24h': 2.07032,
#   'market_cap_change_24h': 28897400,
#   'market_cap_change_percentage_24h': 2.46643,
#   'circulating_supply': 48814965000.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.092868,
#   'ath_change_percentage': -73.50923,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 1.262e-05,
#   'atl_change_percentage': 194820.46299,
#   'atl_date': '2015-12-28T00:00:00.000Z',
#   'roi': {'times': 1.2529907470757213,
#    'currency': 'btc',
#    'percentage': 125.29907470757215},
#   'last_updated': '2021-09-06T21:45:52.708Z'},
#  {'id': 'icon',
#   'symbol': 'icx',
#   'name': 'ICON',
#   'image': 'https://assets.coingecko.com/coins/images/1060/large/icon-icx-logo.png?1547035003',
#   'current_price': 1.74,
#   'market_cap': 1165803700,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 108516931,
#   'high_24h': 1.83,
#   'low_24h': 1.7,
#   'price_change_24h': -0.003082770253,
#   'price_change_percentage_24h': -0.17689,
#   'market_cap_change_24h': -1040137.6960425377,
#   'market_cap_change_percentage_24h': -0.08914,
#   'circulating_supply': 670877213.823163,
#   'total_supply': 800460000.0,
#   'max_supply': None,
#   'ath': 13.16,
#   'ath_change_percentage': -86.7957,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.107465,
#   'atl_change_percentage': 1517.52746,
#   'atl_date': '2020-01-03T02:14:53.139Z',
#   'roi': {'times': 14.815218229421754,
#    'currency': 'usd',
#    'percentage': 1481.5218229421755},
#   'last_updated': '2021-09-06T21:45:46.440Z'}]

# %%
df = (pd.DataFrame(response))
print (df)
# Out:
#                                                      0
# 0    b'[{"id":"bitcoin","symbol":"btc","name":"Bitc...
# 1    b'79","current_price":52051,"market_cap":97666...
# 2    b'5794929744,"high_24h":52034,"low_24h":51134,...
# 3    b'4h":8694960131,"market_cap_change_percentage...
# 4    b':21000000.0,"ath":64805,"ath_change_percenta...
# ..                                                 ...
# 612  b'"fully_diluted_valuation":null,"total_volume...
# 613  b'change_percentage_24h":-0.17689,"market_cap_...
# 614  b'ting_supply":670877213.823163,"total_supply"...
# 615  b'e":"2018-01-09T00:00:00.000Z","atl":0.107465...
# 616  b'mes":14.815218229421754,"currency":"usd","pe...
#
# [617 rows x 1 columns]

# %%
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=100&page=1&sparkline=false"
parameters = {
    'vs_currency': 'usd',
    'start':'1',
   'limit':'5000',
    'order': 'market_cap_desc',
      'per_page': 100, 
    'integer': 1, 
    'boolean': 
    'false'}

response = requests.get(url, params=params)
response.json()
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 52064,
#   'market_cap': 976662986912,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1090453815793,
#   'total_volume': 35796301782,
#   'high_24h': 52034,
#   'low_24h': 51134,
#   'price_change_24h': 501.83,
#   'price_change_percentage_24h': 0.97325,
#   'market_cap_change_24h': 8694960131,
#   'market_cap_change_percentage_24h': 0.89827,
#   'circulating_supply': 18808612.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 64805,
#   'ath_change_percentage': -19.87255,
#   'ath_date': '2021-04-14T11:54:46.763Z',
#   'atl': 67.81,
#   'atl_change_percentage': 76477.40445,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:49.652Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 3954.4,
#   'market_cap': 463422200776,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 19970129961,
#   'high_24h': 3963.79,
#   'low_24h': 3875.9,
#   'price_change_24h': 6.24,
#   'price_change_percentage_24h': 0.15795,
#   'market_cap_change_24h': 375456821,
#   'market_cap_change_percentage_24h': 0.08108,
#   'circulating_supply': 117417360.8115,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4356.99,
#   'ath_change_percentage': -9.38458,
#   'ath_date': '2021-05-12T14:41:48.623Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 911747.15746,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 100.61864883760977,
#    'currency': 'btc',
#    'percentage': 10061.864883760976},
#   'last_updated': '2021-09-06T21:47:23.553Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 2.85,
#   'market_cap': 91154580998,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 127920731315,
#   'total_volume': 3541907519,
#   'high_24h': 2.93,
#   'low_24h': 2.82,
#   'price_change_24h': -0.081747487722,
#   'price_change_percentage_24h': -2.78936,
#   'market_cap_change_24h': -2769125857.992325,
#   'market_cap_change_percentage_24h': -2.94827,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -7.91173,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 14665.07704,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:14.781Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 498.29,
#   'market_cap': 76865779896,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 84824256663,
#   'total_volume': 1994062211,
#   'high_24h': 507.34,
#   'low_24h': 491.86,
#   'price_change_24h': -4.566809839609,
#   'price_change_percentage_24h': -0.90817,
#   'market_cap_change_24h': -667296882.4420013,
#   'market_cap_change_percentage_24h': -0.86066,
#   'circulating_supply': 154533651.9,
#   'total_supply': 170533651.9,
#   'max_supply': 170533651.9,
#   'ath': 686.31,
#   'ath_change_percentage': -27.5244,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1249105.33595,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:39.880Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 67939225660,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 76255752134,
#   'high_24h': 1.0,
#   'low_24h': 0.997274,
#   'price_change_24h': 0.00110398,
#   'price_change_percentage_24h': 0.11047,
#   'market_cap_change_24h': 677063134,
#   'market_cap_change_percentage_24h': 1.0066,
#   'circulating_supply': 67907378786.7102,
#   'total_supply': 67907378786.7102,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.38421,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.748,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:05:54.860Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 1.39,
#   'market_cap': 64716662930,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 139049014805,
#   'total_volume': 6814175591,
#   'high_24h': 1.4,
#   'low_24h': 1.29,
#   'price_change_24h': 0.097264,
#   'price_change_percentage_24h': 7.50557,
#   'market_cap_change_24h': 4360481396,
#   'market_cap_change_percentage_24h': 7.22458,
#   'circulating_supply': 46542338341.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -59.08458,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 51664.07935,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:29.370Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/coinmarketcap-solana-200.png?1616489452',
#   'current_price': 164.45,
#   'market_cap': 47482175847,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 79620414758,
#   'total_volume': 5180561665,
#   'high_24h': 164.32,
#   'low_24h': 139.14,
#   'price_change_24h': 24.17,
#   'price_change_percentage_24h': 17.22596,
#   'market_cap_change_24h': 6583165478,
#   'market_cap_change_percentage_24h': 16.09615,
#   'circulating_supply': 291398188.095557,
#   'total_supply': 488630611.0,
#   'max_supply': 488630611.0,
#   'ath': 163.0,
#   'ath_change_percentage': -0.01085,
#   'ath_date': '2021-09-06T21:04:49.294Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 32444.3101,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:58.458Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.308676,
#   'market_cap': 40330294486,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': None,
#   'total_volume': 2252143937,
#   'high_24h': 0.317522,
#   'low_24h': 0.303884,
#   'price_change_24h': -0.002039478698,
#   'price_change_percentage_24h': -0.65638,
#   'market_cap_change_24h': -319923143.06290436,
#   'market_cap_change_percentage_24h': -0.78701,
#   'circulating_supply': 131169791748.707,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -57.97218,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 353700.96297,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:04.489Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776',
#   'current_price': 34.47,
#   'market_cap': 35323303776,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': None,
#   'total_volume': 1651083063,
#   'high_24h': 34.9,
#   'low_24h': 33.33,
#   'price_change_24h': 0.066033,
#   'price_change_percentage_24h': 0.19195,
#   'market_cap_change_24h': 26797251,
#   'market_cap_change_percentage_24h': 0.07592,
#   'circulating_supply': 1027240514.00922,
#   'total_supply': 1108189646.81232,
#   'max_supply': None,
#   'ath': 49.35,
#   'ath_change_percentage': -30.30278,
#   'ath_date': '2021-05-15T03:59:58.961Z',
#   'atl': 2.7,
#   'atl_change_percentage': 1175.08559,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:09.480Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 27857438533,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': None,
#   'total_volume': 1956506258,
#   'high_24h': 1.0,
#   'low_24h': 0.996132,
#   'price_change_24h': 0.00195233,
#   'price_change_percentage_24h': 0.19522,
#   'market_cap_change_24h': 62827389,
#   'market_cap_change_percentage_24h': 0.22604,
#   'circulating_supply': 27823772037.8592,
#   'total_supply': 27821880750.8992,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.62396,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 12.26241,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:22.005Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 35.64,
#   'market_cap': 16066075423,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 35662008237,
#   'total_volume': 2466452060,
#   'high_24h': 36.06,
#   'low_24h': 32.67,
#   'price_change_24h': 2.6,
#   'price_change_percentage_24h': 7.87435,
#   'market_cap_change_24h': 1212553780,
#   'market_cap_change_percentage_24h': 8.16341,
#   'circulating_supply': 450509553.9174637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -32.32552,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 23966.25819,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:13.360Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 29.6,
#   'market_cap': 15360908327,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 29548312051,
#   'total_volume': 673567152,
#   'high_24h': 30.21,
#   'low_24h': 28.77,
#   'price_change_24h': 0.325501,
#   'price_change_percentage_24h': 1.11185,
#   'market_cap_change_24h': 136859087,
#   'market_cap_change_percentage_24h': 0.89897,
#   'circulating_supply': 519857388.1320768,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -34.21096,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 2768.56864,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:47.711Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 794.29,
#   'market_cap': 14938402761,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 16652014030,
#   'total_volume': 5883426676,
#   'high_24h': 797.98,
#   'low_24h': 741.62,
#   'price_change_24h': 51.12,
#   'price_change_percentage_24h': 6.8783,
#   'market_cap_change_24h': 961753024,
#   'market_cap_change_percentage_24h': 6.88114,
#   'circulating_supply': 18838949.8967887,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -79.05465,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 930.68196,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:46:55.067Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 222.96,
#   'market_cap': 14873978878,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': None,
#   'total_volume': 3794999360,
#   'high_24h': 230.97,
#   'low_24h': 219.68,
#   'price_change_24h': -3.160876597518,
#   'price_change_percentage_24h': -1.39788,
#   'market_cap_change_24h': -176008039.40234184,
#   'market_cap_change_percentage_24h': -1.16949,
#   'circulating_supply': 66752614.5153875,
#   'total_supply': 84000000.0,
#   'max_supply': None,
#   'ath': 410.26,
#   'ath_change_percentage': -45.6879,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 19295.24057,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:01.117Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 32.4,
#   'market_cap': 12982926591,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 907000073,
#   'high_24h': 35.15,
#   'low_24h': 31.38,
#   'price_change_24h': -2.599985708893,
#   'price_change_percentage_24h': -7.42762,
#   'market_cap_change_24h': -966419618.8927498,
#   'market_cap_change_percentage_24h': -6.92806,
#   'circulating_supply': 400493292.02888,
#   'total_supply': 994421190.941183,
#   'max_supply': None,
#   'ath': 36.61,
#   'ath_change_percentage': -11.42049,
#   'ath_date': '2021-08-29T08:14:44.747Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 26525.55402,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:42.758Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 1.0,
#   'market_cap': 12555385630,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': None,
#   'total_volume': 6787616398,
#   'high_24h': 1.0,
#   'low_24h': 0.995727,
#   'price_change_24h': 0.00267996,
#   'price_change_percentage_24h': 0.26835,
#   'market_cap_change_24h': 44454916,
#   'market_cap_change_percentage_24h': 0.35533,
#   'circulating_supply': 12553977646.51,
#   'total_supply': 12553977646.51,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.34612,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 10.99016,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:56.906Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 80.0,
#   'market_cap': 12552408064,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 37480961613,
#   'total_volume': 1173787234,
#   'high_24h': 86.47,
#   'low_24h': 77.87,
#   'price_change_24h': 0.464859,
#   'price_change_percentage_24h': 0.58449,
#   'market_cap_change_24h': 95246573,
#   'market_cap_change_percentage_24h': 0.76459,
#   'circulating_supply': 157140097.36,
#   'total_supply': 469213710.0,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -88.59897,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 27.44,
#   'atl_change_percentage': 191.14912,
#   'atl_date': '2021-07-20T10:14:50.919Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:55.871Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 108.36,
#   'market_cap': 11057934897,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 213040935821,
#   'total_volume': 2960038481,
#   'high_24h': 117.87,
#   'low_24h': 106.11,
#   'price_change_24h': -9.504399871462,
#   'price_change_percentage_24h': -8.06364,
#   'market_cap_change_24h': -1005339210.0320759,
#   'market_cap_change_percentage_24h': -8.33388,
#   'circulating_supply': 102365769.0,
#   'total_supply': 1972167446.0,
#   'max_supply': 1972167446.0,
#   'ath': 236.84,
#   'ath_change_percentage': -54.42919,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 438.04693,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:01.125Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 1.65,
#   'market_cap': 10959697266,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 16483092871,
#   'total_volume': 1574143840,
#   'high_24h': 1.71,
#   'low_24h': 1.6,
#   'price_change_24h': -0.035680858109,
#   'price_change_percentage_24h': -2.11645,
#   'market_cap_change_24h': -167856988.63572884,
#   'market_cap_change_percentage_24h': -1.50848,
#   'circulating_supply': 6649053883.1,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.62,
#   'ath_change_percentage': -37.07782,
#   'ath_date': '2021-05-18T19:38:18.813Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 52347.67068,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 626.4542096998019,
#    'currency': 'usd',
#    'percentage': 62645.42096998019},
#   'last_updated': '2021-09-06T21:47:56.547Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 52080,
#   'market_cap': 10561023348,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 10561023348,
#   'total_volume': 288120590,
#   'high_24h': 52025,
#   'low_24h': 51159,
#   'price_change_24h': 583.12,
#   'price_change_percentage_24h': 1.13235,
#   'market_cap_change_24h': 294856513,
#   'market_cap_change_percentage_24h': 2.87212,
#   'circulating_supply': 203121.30943419,
#   'total_supply': 203121.30943419,
#   'max_supply': 203121.30943419,
#   'ath': 64565,
#   'ath_change_percentage': -19.4711,
#   'ath_date': '2021-04-14T12:00:05.340Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1556.28561,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:47.904Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 46.84,
#   'market_cap': 10279978263,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 33631415840,
#   'total_volume': 1118975265,
#   'high_24h': 50.94,
#   'low_24h': 45.95,
#   'price_change_24h': -2.025645838521,
#   'price_change_percentage_24h': -4.14533,
#   'market_cap_change_24h': -445171342.6966076,
#   'market_cap_change_percentage_24h': -4.15072,
#   'circulating_supply': 220079475.228676,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 59.4,
#   'ath_change_percentage': -21.26213,
#   'ath_date': '2021-02-10T22:23:34.616Z',
#   'atl': 2.8,
#   'atl_change_percentage': 1569.83034,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:08.076Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.150807,
#   'market_cap': 10038232368,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': None,
#   'total_volume': 754942252,
#   'high_24h': 0.155858,
#   'low_24h': 0.149209,
#   'price_change_24h': -0.001389863857,
#   'price_change_percentage_24h': -0.9132,
#   'market_cap_change_24h': -110112711.83511925,
#   'market_cap_change_percentage_24h': -1.08503,
#   'circulating_supply': 66760741299.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -46.48894,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 7743.02813,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 12.344313664081184,
#    'currency': 'eth',
#    'percentage': 1234.4313664081185},
#   'last_updated': '2021-09-06T21:48:07.875Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.424215,
#   'market_cap': 10023282236,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 21182719779,
#   'total_volume': 1628444880,
#   'high_24h': 0.428308,
#   'low_24h': 0.390024,
#   'price_change_24h': 0.03165998,
#   'price_change_percentage_24h': 8.0651,
#   'market_cap_change_24h': 722201101,
#   'market_cap_change_percentage_24h': 7.7647,
#   'circulating_supply': 23659954306.4565,
#   'total_supply': 50001802828.4414,
#   'max_supply': 50001802828.4414,
#   'ath': 0.875563,
#   'ath_change_percentage': -51.61523,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 88876.75011,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:08.288Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 74.11,
#   'market_cap': 9592888963,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': None,
#   'total_volume': 7758685228,
#   'high_24h': 76.52,
#   'low_24h': 71.77,
#   'price_change_24h': 1.68,
#   'price_change_percentage_24h': 2.31946,
#   'market_cap_change_24h': 209500109,
#   'market_cap_change_percentage_24h': 2.23267,
#   'circulating_supply': 129693726.639632,
#   'total_supply': 210700000.0,
#   'max_supply': None,
#   'ath': 167.09,
#   'ath_change_percentage': -55.73178,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 11926.20212,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 163.67793729596983,
#    'currency': 'usd',
#    'percentage': 16367.793729596982},
#   'last_updated': '2021-09-06T21:48:00.413Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 9.32,
#   'market_cap': 9308712856,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': None,
#   'total_volume': 1001374282,
#   'high_24h': 9.41,
#   'low_24h': 7.91,
#   'price_change_24h': 1.35,
#   'price_change_percentage_24h': 16.96152,
#   'market_cap_change_24h': 1354473489,
#   'market_cap_change_percentage_24h': 17.02832,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -40.78055,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 22942.52101,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 61.1271610186371,
#    'currency': 'usd',
#    'percentage': 6112.71610186371},
#   'last_updated': '2021-09-06T21:48:00.823Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 74.39,
#   'market_cap': 7849209160,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 24951924650,
#   'total_volume': 1804928585,
#   'high_24h': 77.04,
#   'low_24h': 62.43,
#   'price_change_24h': 10.3,
#   'price_change_percentage_24h': 16.06241,
#   'market_cap_change_24h': 1053172219,
#   'market_cap_change_percentage_24h': 15.49686,
#   'circulating_supply': 105957291.21874323,
#   'total_supply': 336828627.285971,
#   'max_supply': 336828627.285971,
#   'ath': 77.04,
#   'ath_change_percentage': -3.80781,
#   'ath_date': '2021-09-06T14:14:49.165Z',
#   'atl': 1.15,
#   'atl_change_percentage': 6345.37939,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:57.138Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 79.2,
#   'market_cap': 7436162135,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': None,
#   'total_volume': 20797896,
#   'high_24h': 79.56,
#   'low_24h': 77.82,
#   'price_change_24h': 0.098685,
#   'price_change_percentage_24h': 0.12476,
#   'market_cap_change_24h': 27947662,
#   'market_cap_change_percentage_24h': 0.37725,
#   'circulating_supply': 93939211.0863374,
#   'total_supply': 93939211.0863374,
#   'max_supply': None,
#   'ath': 87.15,
#   'ath_change_percentage': -9.16459,
#   'ath_date': '2021-05-12T14:49:23.076Z',
#   'atl': 1.89,
#   'atl_change_percentage': 4096.56451,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:24.599Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.103831,
#   'market_cap': 7424656064,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 1399411528,
#   'high_24h': 0.107184,
#   'low_24h': 0.102337,
#   'price_change_24h': -0.000455241958,
#   'price_change_percentage_24h': -0.43653,
#   'market_cap_change_24h': -34352514.86218643,
#   'market_cap_change_percentage_24h': -0.46055,
#   'circulating_supply': 71660220128.0,
#   'total_supply': 100850743812.0,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -55.27779,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 5642.21477,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 53.64809520289926,
#    'currency': 'usd',
#    'percentage': 5364.809520289927},
#   'last_updated': '2021-09-06T21:47:54.835Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 25.53,
#   'market_cap': 7111146601,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 710945023,
#   'high_24h': 26.9,
#   'low_24h': 24.78,
#   'price_change_24h': 0.082346,
#   'price_change_percentage_24h': 0.32361,
#   'market_cap_change_24h': 38315690,
#   'market_cap_change_percentage_24h': 0.54173,
#   'circulating_supply': 278741933.433749,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 31.7,
#   'ath_change_percentage': -19.52622,
#   'ath_date': '2021-05-07T16:18:33.469Z',
#   'atl': 1.16,
#   'atl_change_percentage': 2099.17701,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 254.2818690103882,
#    'currency': 'usd',
#    'percentage': 25428.18690103882},
#   'last_updated': '2021-09-06T21:48:05.795Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 23.29,
#   'market_cap': 6231095028,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': None,
#   'total_volume': 350660343,
#   'high_24h': 23.87,
#   'low_24h': 22.77,
#   'price_change_24h': 0.245301,
#   'price_change_percentage_24h': 1.06431,
#   'market_cap_change_24h': 68244433,
#   'market_cap_change_percentage_24h': 1.10735,
#   'circulating_supply': 267436117.72,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -47.05325,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 3912.9274,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:09.751Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/dai-multi-collateral-mcd.png?1574218774',
#   'current_price': 1.0,
#   'market_cap': 6182088644,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 6182088644,
#   'total_volume': 421948081,
#   'high_24h': 1.0,
#   'low_24h': 0.997199,
#   'price_change_24h': -0.003588456359,
#   'price_change_percentage_24h': -0.35755,
#   'market_cap_change_24h': 17653001,
#   'market_cap_change_percentage_24h': 0.28637,
#   'circulating_supply': 6181931826.52944,
#   'total_supply': 6181931826.52944,
#   'max_supply': 6181931826.52944,
#   'ath': 1.22,
#   'ath_change_percentage': -17.95878,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.71498,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:05:28.974Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 6.19,
#   'market_cap': 5977679550,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': None,
#   'total_volume': 2826168340,
#   'high_24h': 6.37,
#   'low_24h': 6.01,
#   'price_change_24h': -0.042103417811,
#   'price_change_percentage_24h': -0.67558,
#   'market_cap_change_24h': -38348279.23418522,
#   'market_cap_change_percentage_24h': -0.63744,
#   'circulating_supply': 966290625.2354,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -72.76152,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 1131.33105,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': 5.252621652524265,
#    'currency': 'usd',
#    'percentage': 525.2621652524266},
#   'last_updated': '2021-09-06T21:47:43.411Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 316.88,
#   'market_cap': 5690157627,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': None,
#   'total_volume': 302606353,
#   'high_24h': 320.65,
#   'low_24h': 305.24,
#   'price_change_24h': 2.24,
#   'price_change_percentage_24h': 0.71242,
#   'market_cap_change_24h': 39121139,
#   'market_cap_change_percentage_24h': 0.69228,
#   'circulating_supply': 17987923.6204643,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -41.6514,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 146279.9847,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:55.736Z'},
#  {'id': 'bitcoin-cash-abc-2',
#   'symbol': 'bcha',
#   'name': 'Bitcoin Cash ABC',
#   'image': 'https://assets.coingecko.com/coins/images/13120/large/Logo_final-21.png?1624892810',
#   'current_price': 295.03,
#   'market_cap': 5546373575,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': None,
#   'total_volume': 731858771,
#   'high_24h': 328.45,
#   'low_24h': 288.64,
#   'price_change_24h': -15.976144512727,
#   'price_change_percentage_24h': -5.13685,
#   'market_cap_change_24h': -315368915.5532589,
#   'market_cap_change_percentage_24h': -5.38012,
#   'circulating_supply': 18794058.3967894,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 378.12,
#   'ath_change_percentage': -21.95081,
#   'ath_date': '2021-09-04T17:15:31.514Z',
#   'atl': 9.21,
#   'atl_change_percentage': 3104.38888,
#   'atl_date': '2020-11-15T18:28:32.658Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:49.588Z'},
#  {'id': 'ecash',
#   'symbol': 'xec',
#   'name': 'eCash',
#   'image': 'https://assets.coingecko.com/coins/images/16646/large/Logo_final-22.png?1628239446',
#   'current_price': 0.00029,
#   'market_cap': 5453534836,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 434157264,
#   'high_24h': 0.00031737,
#   'low_24h': 0.00028087,
#   'price_change_24h': -1.7538761e-05,
#   'price_change_percentage_24h': -5.70295,
#   'market_cap_change_24h': 5453534836,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 18836114646789.4,
#   'total_supply': 21000000000000.0,
#   'max_supply': None,
#   'ath': 0.00038001,
#   'ath_change_percentage': -23.81175,
#   'ath_date': '2021-09-04T17:09:31.137Z',
#   'atl': 1.847e-05,
#   'atl_change_percentage': 1467.55204,
#   'atl_date': '2021-07-20T20:49:46.212Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:53.179Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 412.1,
#   'market_cap': 5417403129,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 6589387235,
#   'total_volume': 396513344,
#   'high_24h': 423.81,
#   'low_24h': 404.91,
#   'price_change_24h': -8.394608774613,
#   'price_change_percentage_24h': -1.99637,
#   'market_cap_change_24h': -103775860.22286606,
#   'market_cap_change_percentage_24h': -1.8796,
#   'circulating_supply': 13154250.461165803,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -37.75319,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 1482.74837,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:56.256Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://assets.coingecko.com/coins/images/12632/large/pancakeswap-cake-logo_%281%29.png?1629359065',
#   'current_price': 24.67,
#   'market_cap': 5374495526,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': None,
#   'total_volume': 291483263,
#   'high_24h': 25.22,
#   'low_24h': 24.18,
#   'price_change_24h': 0.347734,
#   'price_change_percentage_24h': 1.42988,
#   'market_cap_change_24h': 72737963,
#   'market_cap_change_percentage_24h': 1.37196,
#   'circulating_supply': 218284410.742696,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 43.96,
#   'ath_change_percentage': -43.9927,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 12563.71236,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:28.351Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 1.05,
#   'market_cap': 5200823776,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 10492205291,
#   'total_volume': 412436916,
#   'high_24h': 1.06,
#   'low_24h': 0.976856,
#   'price_change_24h': 0.052202,
#   'price_change_percentage_24h': 5.22751,
#   'market_cap_change_24h': 253357017,
#   'market_cap_change_percentage_24h': 5.12094,
#   'circulating_supply': 4956845231.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -63.07315,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 916.20753,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:05.389Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02221203,
#   'market_cap': 5176814906,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': None,
#   'total_volume': 48801423,
#   'high_24h': 0.02221247,
#   'low_24h': 0.02206443,
#   'price_change_24h': 6.729e-05,
#   'price_change_percentage_24h': 0.30386,
#   'market_cap_change_24h': 45787537,
#   'market_cap_change_percentage_24h': 0.89237,
#   'circulating_supply': 233487969512.303,
#   'total_supply': 233487969512.303,
#   'max_supply': None,
#   'ath': 0.058843,
#   'ath_change_percentage': -62.32092,
#   'ath_date': '2020-10-21T11:24:27.820Z',
#   'atl': 0.00620705,
#   'atl_change_percentage': 257.20093,
#   'atl_date': '2021-03-04T08:11:37.438Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:23.420Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 1.84,
#   'market_cap': 5125407858,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': None,
#   'total_volume': 342181586,
#   'high_24h': 1.95,
#   'low_24h': 1.77,
#   'price_change_24h': 0.0594,
#   'price_change_percentage_24h': 3.32683,
#   'market_cap_change_24h': 167465062,
#   'market_cap_change_percentage_24h': 3.37771,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -64.86833,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 2158.74913,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 25.455361917931494,
#    'currency': 'btc',
#    'percentage': 2545.536191793149},
#   'last_updated': '2021-09-06T21:48:02.613Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.200905,
#   'market_cap': 5068215767,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': None,
#   'total_volume': 91772703,
#   'high_24h': 0.200887,
#   'low_24h': 0.183343,
#   'price_change_24h': 0.01522382,
#   'price_change_percentage_24h': 8.19891,
#   'market_cap_change_24h': 384993715,
#   'market_cap_change_percentage_24h': 8.2207,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.27702,
#   'ath_change_percentage': -27.49747,
#   'ath_date': '2021-02-22T11:33:57.751Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1557.20457,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:47.930Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 1.42,
#   'market_cap': 4993700987,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 14171853071,
#   'total_volume': 481821919,
#   'high_24h': 1.44,
#   'low_24h': 1.3,
#   'price_change_24h': 0.102138,
#   'price_change_percentage_24h': 7.74603,
#   'market_cap_change_24h': 347488946,
#   'market_cap_change_percentage_24h': 7.47897,
#   'circulating_supply': 3523675387.98048,
#   'total_supply': 5763239775.93481,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -60.19143,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 1245.83718,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.4080316716533208,
#    'currency': 'usd',
#    'percentage': -40.803167165332084},
#   'last_updated': '2021-09-06T21:47:47.288Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 5.7,
#   'market_cap': 4787873509,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': None,
#   'total_volume': 385726874,
#   'high_24h': 5.73,
#   'low_24h': 5.4,
#   'price_change_24h': 0.18803,
#   'price_change_percentage_24h': 3.41383,
#   'market_cap_change_24h': 147651803,
#   'market_cap_change_percentage_24h': 3.182,
#   'circulating_supply': 843704693.712206,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 8.27,
#   'ath_change_percentage': -31.34954,
#   'ath_date': '2021-05-07T02:09:26.683Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 1519.17551,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 11.118953023369063,
#    'currency': 'usd',
#    'percentage': 1111.895302336906},
#   'last_updated': '2021-09-06T21:47:49.779Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02165253,
#   'market_cap': 4712013756,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 111752412,
#   'high_24h': 0.02164635,
#   'low_24h': 0.0215142,
#   'price_change_24h': 6.123e-05,
#   'price_change_percentage_24h': 0.28356,
#   'market_cap_change_24h': 113573396,
#   'market_cap_change_percentage_24h': 2.46982,
#   'circulating_supply': 218010314664.599,
#   'total_supply': 218010314664.599,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -31.58238,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 196.54373,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:45:24.188Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 80.75,
#   'market_cap': 4668559011,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 21798839965,
#   'total_volume': 985241445,
#   'high_24h': 84.56,
#   'low_24h': 76.43,
#   'price_change_24h': -1.895517988092,
#   'price_change_percentage_24h': -2.29345,
#   'market_cap_change_24h': -99458777.5863514,
#   'market_cap_change_percentage_24h': -2.08596,
#   'circulating_supply': 57824679.437666714,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 93.68,
#   'ath_change_percentage': -13.82929,
#   'ath_date': '2021-09-04T14:30:06.167Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 65150.72694,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:02.988Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 3924.69,
#   'market_cap': 4657227486,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 4657227486,
#   'total_volume': 16749939,
#   'high_24h': 3943.29,
#   'low_24h': 3864.15,
#   'price_change_24h': -2.650915520602,
#   'price_change_percentage_24h': -0.0675,
#   'market_cap_change_24h': 21802669,
#   'market_cap_change_percentage_24h': 0.47035,
#   'circulating_supply': 1187456.85450562,
#   'total_supply': 1187456.85450562,
#   'max_supply': 1187456.85450562,
#   'ath': 4309.29,
#   'ath_change_percentage': -8.94949,
#   'ath_date': '2021-05-12T09:57:17.253Z',
#   'atl': 482.9,
#   'atl_change_percentage': 712.52075,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:43:14.574Z'},
#  {'id': 'neo',
#   'symbol': 'neo',
#   'name': 'NEO',
#   'image': 'https://assets.coingecko.com/coins/images/480/large/NEO_512_512.png?1594357361',
#   'current_price': 64.0,
#   'market_cap': 4501904109,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': None,
#   'total_volume': 1111056717,
#   'high_24h': 66.31,
#   'low_24h': 62.26,
#   'price_change_24h': 1.24,
#   'price_change_percentage_24h': 1.98293,
#   'market_cap_change_24h': 87368420,
#   'market_cap_change_percentage_24h': 1.97911,
#   'circulating_supply': 70530000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 198.38,
#   'ath_change_percentage': -67.82478,
#   'ath_date': '2018-01-15T00:00:00.000Z',
#   'atl': 0.078349,
#   'atl_change_percentage': 81367.92997,
#   'atl_date': '2016-10-21T00:00:00.000Z',
#   'roi': {'times': 1776.6473203007617,
#    'currency': 'usd',
#    'percentage': 177664.73203007618},
#   'last_updated': '2021-09-06T21:47:58.682Z'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'image': 'https://assets.coingecko.com/coins/images/3370/large/5ZOu7brX_400x400.jpg?1612437252',
#   'current_price': 340.56,
#   'market_cap': 4470271596,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 4938943518,
#   'total_volume': 713282124,
#   'high_24h': 379.03,
#   'low_24h': 290.01,
#   'price_change_24h': 50.56,
#   'price_change_percentage_24h': 17.43357,
#   'market_cap_change_24h': 672413710,
#   'market_cap_change_percentage_24h': 17.70508,
#   'circulating_supply': 13225867.469289193,
#   'total_supply': 14612493.0,
#   'max_supply': 14612493.0,
#   'ath': 379.03,
#   'ath_change_percentage': -10.82534,
#   'ath_date': '2021-09-06T04:44:25.671Z',
#   'atl': 0.215773,
#   'atl_change_percentage': 156543.35187,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'roi': {'times': 36.03216952042438,
#    'currency': 'eth',
#    'percentage': 3603.216952042438},
#   'last_updated': '2021-09-06T21:47:57.625Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 1.63,
#   'market_cap': 4070835041,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': None,
#   'total_volume': 61928121,
#   'high_24h': 1.66,
#   'low_24h': 1.6,
#   'price_change_24h': 0.02211489,
#   'price_change_percentage_24h': 1.3774,
#   'market_cap_change_24h': 58937818,
#   'market_cap_change_percentage_24h': 1.46908,
#   'circulating_supply': 2502010658.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -62.50367,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 2591.83393,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:38.726Z'},
#  {'id': 'fantom',
#   'symbol': 'ftm',
#   'name': 'Fantom',
#   'image': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#   'current_price': 1.42,
#   'market_cap': 3655958329,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 4567874867,
#   'total_volume': 1021070196,
#   'high_24h': 1.46,
#   'low_24h': 1.2,
#   'price_change_24h': 0.200304,
#   'price_change_percentage_24h': 16.36692,
#   'market_cap_change_24h': 530375861,
#   'market_cap_change_percentage_24h': 16.96886,
#   'circulating_supply': 2541152731.01,
#   'total_supply': 3175000000.0,
#   'max_supply': 3175000000.0,
#   'ath': 1.46,
#   'ath_change_percentage': -1.63829,
#   'ath_date': '2021-09-06T20:30:28.945Z',
#   'atl': 0.00190227,
#   'atl_change_percentage': 75530.74316,
#   'atl_date': '2020-03-13T02:25:38.280Z',
#   'roi': {'times': 46.471332535344864,
#    'currency': 'usd',
#    'percentage': 4647.133253534486},
#   'last_updated': '2021-09-06T21:47:56.206Z'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'image': 'https://assets.coingecko.com/coins/images/6799/large/BSV.png?1558947902',
#   'current_price': 193.28,
#   'market_cap': 3632386908,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': None,
#   'total_volume': 436550068,
#   'high_24h': 198.91,
#   'low_24h': 188.25,
#   'price_change_24h': 3.07,
#   'price_change_percentage_24h': 1.61197,
#   'market_cap_change_24h': 56223145,
#   'market_cap_change_percentage_24h': 1.57216,
#   'circulating_supply': 18835395.394239,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 489.75,
#   'ath_change_percentage': -60.61101,
#   'ath_date': '2021-04-16T17:09:04.630Z',
#   'atl': 42.02,
#   'atl_change_percentage': 359.1154,
#   'atl_date': '2018-11-23T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:27.539Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 7.22e-06,
#   'market_cap': 3583291618,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': None,
#   'total_volume': 315563047,
#   'high_24h': 7.59e-06,
#   'low_24h': 7.11e-06,
#   'price_change_24h': -2.19511e-07,
#   'price_change_percentage_24h': -2.9489,
#   'market_cap_change_24h': -116544307.05699205,
#   'market_cap_change_percentage_24h': -3.14999,
#   'circulating_supply': 497730966630395.75,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 3.791e-05,
#   'ath_change_percentage': -81.00857,
#   'ath_date': '2021-05-10T22:53:42.945Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 12773545.0073,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:01.159Z'},
#  {'id': 'kusama',
#   'symbol': 'ksm',
#   'name': 'Kusama',
#   'image': 'https://assets.coingecko.com/coins/images/9568/large/m4zRhP5e_400x400.jpg?1576190080',
#   'current_price': 394.71,
#   'market_cap': 3542601714,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 3944947689,
#   'total_volume': 245803435,
#   'high_24h': 405.41,
#   'low_24h': 382.43,
#   'price_change_24h': -7.529307259202,
#   'price_change_percentage_24h': -1.87186,
#   'market_cap_change_24h': -68360910.10213423,
#   'market_cap_change_percentage_24h': -1.89315,
#   'circulating_supply': 8980098.074112339,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 621.71,
#   'ath_change_percentage': -36.53955,
#   'ath_date': '2021-05-18T05:04:41.858Z',
#   'atl': 0.876572,
#   'atl_change_percentage': 44909.04974,
#   'atl_date': '2020-01-14T19:20:20.768Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:14.017Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 178.28,
#   'market_cap': 3511988299,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 121471629,
#   'high_24h': 185.85,
#   'low_24h': 174.96,
#   'price_change_24h': 1.66,
#   'price_change_percentage_24h': 0.94168,
#   'market_cap_change_24h': 38865335,
#   'market_cap_change_percentage_24h': 1.11903,
#   'circulating_supply': 19701871.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 243.92,
#   'ath_change_percentage': -26.87786,
#   'ath_date': '2021-04-12T02:24:35.343Z',
#   'atl': 6.51,
#   'atl_change_percentage': 2641.20486,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
# ...
#   'total_volume': 901475398,
#   'high_24h': 16.79,
#   'low_24h': 15.47,
#   'price_change_24h': 0.145241,
#   'price_change_percentage_24h': 0.92728,
#   'market_cap_change_24h': 8470733,
#   'market_cap_change_percentage_24h': 0.52158,
#   'circulating_supply': 103709998.0,
#   'total_supply': 107822406.0,
#   'max_supply': None,
#   'ath': 100.22,
#   'ath_change_percentage': -84.29409,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 0.783142,
#   'atl_change_percentage': 1909.99168,
#   'atl_date': '2020-03-13T02:22:57.149Z',
#   'roi': {'times': 51.69455513379133,
#    'currency': 'usd',
#    'percentage': 5169.455513379134},
#   'last_updated': '2021-09-06T21:48:06.712Z'},
#  {'id': 'flow',
#   'symbol': 'flow',
#   'name': 'Flow',
#   'image': 'https://assets.coingecko.com/coins/images/13446/large/flow_logo.jpg?1608631239',
#   'current_price': 25.89,
#   'market_cap': 1571532692,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': None,
#   'total_volume': 143018387,
#   'high_24h': 26.5,
#   'low_24h': 25.39,
#   'price_change_24h': 0.110961,
#   'price_change_percentage_24h': 0.43039,
#   'market_cap_change_24h': 12977298,
#   'market_cap_change_percentage_24h': 0.83265,
#   'circulating_supply': 60749508.1158945,
#   'total_supply': 1368390492.48566,
#   'max_supply': None,
#   'ath': 42.4,
#   'ath_change_percentage': -38.97773,
#   'ath_date': '2021-04-05T13:49:10.098Z',
#   'atl': 4.95,
#   'atl_change_percentage': 422.66069,
#   'atl_date': '2021-01-27T15:34:04.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:08.037Z'},
#  {'id': 'yearn-finance',
#   'symbol': 'yfi',
#   'name': 'yearn.finance',
#   'image': 'https://assets.coingecko.com/coins/images/11849/large/yfi-192x192.png?1598325330',
#   'current_price': 41984,
#   'market_cap': 1495422409,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 1536204134,
#   'total_volume': 317820107,
#   'high_24h': 43341,
#   'low_24h': 41727,
#   'price_change_24h': -1315.984115879946,
#   'price_change_percentage_24h': -3.03924,
#   'market_cap_change_24h': -51096625.61359048,
#   'market_cap_change_percentage_24h': -3.30398,
#   'circulating_supply': 35692.624968711796,
#   'total_supply': 36666.0,
#   'max_supply': 36666.0,
#   'ath': 90787,
#   'ath_change_percentage': -53.82644,
#   'ath_date': '2021-05-12T00:29:37.713Z',
#   'atl': 31.65,
#   'atl_change_percentage': 132367.53431,
#   'atl_date': '2020-07-18T12:26:27.150Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:33.232Z'},
#  {'id': 'bitcoin-gold',
#   'symbol': 'btg',
#   'name': 'Bitcoin Gold',
#   'image': 'https://assets.coingecko.com/coins/images/1043/large/bitcoin-gold-logo.png?1547034978',
#   'current_price': 82.65,
#   'market_cap': 1445361967,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': None,
#   'total_volume': 81208964,
#   'high_24h': 84.08,
#   'low_24h': 81.18,
#   'price_change_24h': -0.255637150063,
#   'price_change_percentage_24h': -0.30835,
#   'market_cap_change_24h': -4905892.465975761,
#   'market_cap_change_percentage_24h': -0.33827,
#   'circulating_supply': 17513924.0,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 456.25,
#   'ath_change_percentage': -81.91186,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 4.25,
#   'atl_change_percentage': 1839.76891,
#   'atl_date': '2020-03-13T02:22:52.902Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:52.754Z'},
#  {'id': 'basic-attention-token',
#   'symbol': 'bat',
#   'name': 'Basic Attention Token',
#   'image': 'https://assets.coingecko.com/coins/images/677/large/basic-attention-token.png?1547034427',
#   'current_price': 0.962287,
#   'market_cap': 1432400521,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1441676548,
#   'total_volume': 190573518,
#   'high_24h': 0.98739,
#   'low_24h': 0.936635,
#   'price_change_24h': -0.01078474668,
#   'price_change_percentage_24h': -1.10832,
#   'market_cap_change_24h': -21390489.477897406,
#   'market_cap_change_percentage_24h': -1.47136,
#   'circulating_supply': 1490348708.4473505,
#   'total_supply': 1500000000.0,
#   'max_supply': 1500000000.0,
#   'ath': 1.63,
#   'ath_change_percentage': -41.08507,
#   'ath_date': '2021-04-09T19:03:22.356Z',
#   'atl': 0.072394,
#   'atl_change_percentage': 1227.62422,
#   'atl_date': '2017-07-16T00:00:00.000Z',
#   'roi': {'times': 0.5570129692692858,
#    'currency': 'eth',
#    'percentage': 55.70129692692858},
#   'last_updated': '2021-09-06T21:48:06.843Z'},
#  {'id': 'iostoken',
#   'symbol': 'iost',
#   'name': 'IOST',
#   'image': 'https://assets.coingecko.com/coins/images/2523/large/IOST.png?1557555183',
#   'current_price': 0.062388,
#   'market_cap': 1419881477,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 5620612652,
#   'total_volume': 385574353,
#   'high_24h': 0.062946,
#   'low_24h': 0.058634,
#   'price_change_24h': 0.00152777,
#   'price_change_percentage_24h': 2.51028,
#   'market_cap_change_24h': 37278119,
#   'market_cap_change_percentage_24h': 2.69623,
#   'circulating_supply': 22735836966.197,
#   'total_supply': 22735836966.197,
#   'max_supply': 90000000000.0,
#   'ath': 0.129829,
#   'ath_change_percentage': -51.89717,
#   'ath_date': '2018-01-24T00:00:00.000Z',
#   'atl': 0.00160309,
#   'atl_change_percentage': 3795.68277,
#   'atl_date': '2020-03-13T02:25:35.257Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:01.028Z'},
#  {'id': 'mdex',
#   'symbol': 'mdx',
#   'name': 'Mdex',
#   'image': 'https://assets.coingecko.com/coins/images/13775/large/mdex.png?1611739676',
#   'current_price': 2.15,
#   'market_cap': 1402041669,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': None,
#   'total_volume': 112377247,
#   'high_24h': 2.21,
#   'low_24h': 1.78,
#   'price_change_24h': 0.323735,
#   'price_change_percentage_24h': 17.68703,
#   'market_cap_change_24h': 224977434,
#   'market_cap_change_percentage_24h': 19.11344,
#   'circulating_supply': 650681553.22546,
#   'total_supply': 452988758.45796,
#   'max_supply': None,
#   'ath': 10.11,
#   'ath_change_percentage': -78.68875,
#   'ath_date': '2021-02-22T07:08:38.957Z',
#   'atl': 1.05,
#   'atl_change_percentage': 104.69129,
#   'atl_date': '2021-07-30T09:34:16.681Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:48:13.331Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 1.0,
#   'market_cap': 1401945498,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': None,
#   'total_volume': 66419089,
#   'high_24h': 1.0,
#   'low_24h': 0.995181,
#   'price_change_24h': 0.00235114,
#   'price_change_percentage_24h': 0.23536,
#   'market_cap_change_24h': 12021042,
#   'market_cap_change_percentage_24h': 0.86487,
#   'circulating_supply': 1401641737.0833,
#   'total_supply': 1402016729.5833,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.19974,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.20754,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:56.380Z'},
#  {'id': 'ravencoin',
#   'symbol': 'rvn',
#   'name': 'Ravencoin',
#   'image': 'https://assets.coingecko.com/coins/images/3412/large/ravencoin.png?1548386057',
#   'current_price': 0.145312,
#   'market_cap': 1392684361,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': None,
#   'total_volume': 126874571,
#   'high_24h': 0.152441,
#   'low_24h': 0.142232,
#   'price_change_24h': -0.005275803281,
#   'price_change_percentage_24h': -3.50346,
#   'market_cap_change_24h': -47966531.9770987,
#   'market_cap_change_percentage_24h': -3.3295,
#   'circulating_supply': 9593530000.0,
#   'total_supply': 21000000000.0,
#   'max_supply': None,
#   'ath': 0.285218,
#   'ath_change_percentage': -49.1024,
#   'ath_date': '2021-02-20T11:19:07.791Z',
#   'atl': 0.00893232,
#   'atl_change_percentage': 1525.21134,
#   'atl_date': '2020-03-13T02:30:00.004Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:57.364Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 1.04,
#   'market_cap': 1376767384,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 2275737022,
#   'total_volume': 174137696,
#   'high_24h': 1.08,
#   'low_24h': 1.02,
#   'price_change_24h': -0.022209557966,
#   'price_change_percentage_24h': -2.09278,
#   'market_cap_change_24h': -27492982.41645074,
#   'market_cap_change_percentage_24h': -1.95783,
#   'circulating_supply': 1327372145.9864838,
#   'total_supply': 2194088827.32015,
#   'max_supply': 2194088827.32015,
#   'ath': 1.6,
#   'ath_change_percentage': -35.0377,
#   'ath_date': '2021-05-07T15:54:15.763Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 11129.126,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 50.95184199770425,
#    'currency': 'usd',
#    'percentage': 5095.184199770425},
#   'last_updated': '2021-09-06T21:47:54.344Z'},
#  {'id': 'harmony',
#   'symbol': 'one',
#   'name': 'Harmony',
#   'image': 'https://assets.coingecko.com/coins/images/4344/large/Y88JAze.png?1565065793',
#   'current_price': 0.130525,
#   'market_cap': 1375900151,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 1716635899,
#   'total_volume': 68738548,
#   'high_24h': 0.133389,
#   'low_24h': 0.126477,
#   'price_change_24h': -0.001458409564,
#   'price_change_percentage_24h': -1.10499,
#   'market_cap_change_24h': -12743264.716475964,
#   'market_cap_change_percentage_24h': -0.91768,
#   'circulating_supply': 10544696227.7931,
#   'total_supply': 13156044839.793139,
#   'max_supply': 13156044839.793139,
#   'ath': 0.222092,
#   'ath_change_percentage': -41.24842,
#   'ath_date': '2021-03-29T08:19:36.363Z',
#   'atl': 0.00127355,
#   'atl_change_percentage': 10145.5702,
#   'atl_date': '2020-03-13T02:24:14.005Z',
#   'roi': {'times': 40.11032055469379,
#    'currency': 'usd',
#    'percentage': 4011.0320554693794},
#   'last_updated': '2021-09-06T21:47:51.159Z'},
#  {'id': 'telcoin',
#   'symbol': 'tel',
#   'name': 'Telcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1899/large/tel.png?1547036203',
#   'current_price': 0.02380236,
#   'market_cap': 1347183933,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': None,
#   'total_volume': 17677722,
#   'high_24h': 0.02472607,
#   'low_24h': 0.02296479,
#   'price_change_24h': -0.000881568248,
#   'price_change_percentage_24h': -3.57143,
#   'market_cap_change_24h': -56343133.87691951,
#   'market_cap_change_percentage_24h': -4.0144,
#   'circulating_supply': 56989406904.06,
#   'total_supply': 100000000000.0,
#   'max_supply': None,
#   'ath': 0.064483,
#   'ath_change_percentage': -63.34027,
#   'ath_date': '2021-05-11T00:32:24.043Z',
#   'atl': 6.474e-05,
#   'atl_change_percentage': 36416.16057,
#   'atl_date': '2020-03-13T02:24:47.992Z',
#   'roi': {'times': 22.80236292193171,
#    'currency': 'usd',
#    'percentage': 2280.236292193171},
#   'last_updated': '2021-09-06T21:47:54.540Z'},
#  {'id': 'omisego',
#   'symbol': 'omg',
#   'name': 'OMG Network',
#   'image': 'https://assets.coingecko.com/coins/images/776/large/OMG_Network.jpg?1591167168',
#   'current_price': 9.27,
#   'market_cap': 1294423754,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 1294423754,
#   'total_volume': 2815665449,
#   'high_24h': 10.04,
#   'low_24h': 7.96,
#   'price_change_24h': 1.31,
#   'price_change_percentage_24h': 16.4644,
#   'market_cap_change_24h': 184444392,
#   'market_cap_change_percentage_24h': 16.61692,
#   'circulating_supply': 140245398.245133,
#   'total_supply': 140245398.245133,
#   'max_supply': 140245398.245133,
#   'ath': 25.62,
#   'ath_change_percentage': -63.97559,
#   'ath_date': '2018-01-13T00:00:00.000Z',
#   'atl': 0.350917,
#   'atl_change_percentage': 2530.16684,
#   'atl_date': '2020-03-13T02:30:10.072Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:39.306Z'},
#  {'id': 'safemoon',
#   'symbol': 'safemoon',
#   'name': 'SafeMoon',
#   'image': 'https://assets.coingecko.com/coins/images/14362/large/174x174-white.png?1617174846',
#   'current_price': 2.21e-06,
#   'market_cap': 1270541551,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': None,
#   'total_volume': 13085978,
#   'high_24h': 2.42e-06,
#   'low_24h': 2.16e-06,
#   'price_change_24h': -1.97358e-07,
#   'price_change_percentage_24h': -8.21445,
#   'market_cap_change_24h': -102998284.44188571,
#   'market_cap_change_percentage_24h': -7.49875,
#   'circulating_supply': 576736249684172.6,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 1.094e-05,
#   'ath_change_percentage': -79.86941,
#   'ath_date': '2021-05-11T20:32:53.513Z',
#   'atl': 4.436e-08,
#   'atl_change_percentage': 4866.20113,
#   'atl_date': '2021-03-14T19:51:56.741Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:38.152Z'},
#  {'id': 'zencash',
#   'symbol': 'zen',
#   'name': 'Horizen',
#   'image': 'https://assets.coingecko.com/coins/images/691/large/horizen.png?1555052241',
#   'current_price': 105.93,
#   'market_cap': 1216692912,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 57397624,
#   'high_24h': 110.31,
#   'low_24h': 104.81,
#   'price_change_24h': -3.655313413193,
#   'price_change_percentage_24h': -3.33548,
#   'market_cap_change_24h': -37568999.62813592,
#   'market_cap_change_percentage_24h': -2.99531,
#   'circulating_supply': 11491706.25,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 165.92,
#   'ath_change_percentage': -36.16909,
#   'ath_date': '2021-05-08T06:00:30.087Z',
#   'atl': 3.26,
#   'atl_change_percentage': 3144.1801,
#   'atl_date': '2019-10-17T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:47:55.413Z'},
#  {'id': 'xsushi',
#   'symbol': 'xsushi',
#   'name': 'xSUSHI',
#   'image': 'https://assets.coingecko.com/coins/images/13725/large/xsushi.png?1612538526',
#   'current_price': 16.19,
#   'market_cap': 1213102633,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': None,
#   'total_volume': 1567199,
#   'high_24h': 16.8,
#   'low_24h': 15.94,
#   'price_change_24h': -0.561941226756,
#   'price_change_percentage_24h': -3.35419,
#   'market_cap_change_24h': -40900178.214959145,
#   'market_cap_change_percentage_24h': -3.26157,
#   'circulating_supply': 74922326.6650337,
#   'total_supply': 74922326.6650337,
#   'max_supply': None,
#   'ath': 26.33,
#   'ath_change_percentage': -38.5057,
#   'ath_date': '2021-03-13T23:01:02.266Z',
#   'atl': 6.04,
#   'atl_change_percentage': 168.02181,
#   'atl_date': '2021-01-22T01:04:22.350Z',
#   'roi': None,
#   'last_updated': '2021-09-06T21:42:00.902Z'},
#  {'id': 'siacoin',
#   'symbol': 'sc',
#   'name': 'Siacoin',
#   'image': 'https://assets.coingecko.com/coins/images/289/large/siacoin.png?1548386465',
#   'current_price': 0.02461739,
#   'market_cap': 1200528322,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': None,
#   'total_volume': 183246965,
#   'high_24h': 0.02551302,
#   'low_24h': 0.02387008,
#   'price_change_24h': 0.00050625,
#   'price_change_percentage_24h': 2.09967,
#   'market_cap_change_24h': 28897400,
#   'market_cap_change_percentage_24h': 2.46643,
#   'circulating_supply': 48814965000.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.092868,
#   'ath_change_percentage': -73.50923,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 1.262e-05,
#   'atl_change_percentage': 194820.46299,
#   'atl_date': '2015-12-28T00:00:00.000Z',
#   'roi': {'times': 1.2531118578057638,
#    'currency': 'btc',
#    'percentage': 125.31118578057638},
#   'last_updated': '2021-09-06T21:47:39.851Z'},
#  {'id': 'icon',
#   'symbol': 'icx',
#   'name': 'ICON',
#   'image': 'https://assets.coingecko.com/coins/images/1060/large/icon-icx-logo.png?1547035003',
#   'current_price': 1.74,
#   'market_cap': 1165803700,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 101023538,
#   'high_24h': 1.83,
#   'low_24h': 1.7,
#   'price_change_24h': -0.000188699055,
#   'price_change_percentage_24h': -0.01083,
#   'market_cap_change_24h': -1040137.6960425377,
#   'market_cap_change_percentage_24h': -0.08914,
#   'circulating_supply': 670877213.823163,
#   'total_supply': 800460000.0,
#   'max_supply': None,
#   'ath': 13.16,
#   'ath_change_percentage': -86.7957,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.107465,
#   'atl_change_percentage': 1517.52746,
#   'atl_date': '2020-01-03T02:14:53.139Z',
#   'roi': {'times': 14.841527967585192,
#    'currency': 'usd',
#    'percentage': 1484.1527967585191},
#   'last_updated': '2021-09-06T21:47:59.369Z'}]
